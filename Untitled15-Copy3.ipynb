# %%
import numpy as np 
import matplotlib.pyplot as plt
import sympy as sp
import scipy.optimize as opt 
from scipy import integrate as ig

# %matplotlib inline

# %%
ε_AA = 238 # кал/моль
σ_AA = 3.4 # Ангстрем - диаметр жёсткой сферы молекулы
r = 2**(1/6)*σ_AA
ε = 4*ε_AA*((σ_AA/r)**6-(σ_AA/r)**12)
R = 2 # кал/(моль*К) - газовая постоянная 
T_kr = 146.6 # К - критическая температура
#T = 146.6 # начальное значение температуры
z_1 = 6
z_2 = 12

# %%
def f1(θ):
    return θ*(1+2*θ*(np.exp(-(R*T)**(-1)*ε)-1)/(1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ)+((1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ))**2+4*(np.exp(-(R*T)**(-1)*ε)-1)*θ**2)**0.5))**z_1/(1-θ)
def f1_minus(θ):
    return -(θ*(1+2*θ*(np.exp(-(R*T)**(-1)*ε)-1)/(1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ)+((1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ))**2+4*(np.exp(-(R*T)**(-1)*ε)-1)*θ**2)**0.5))**z_1/(1-θ))

# %%
phase_diagram = []
T=146.6
phase_diagram.append([0.5, f1(0.5)]) #заношу в базу первую точку фазы
print(phase_diagram)
# Out:
# [[0.5, 0.08758042042172726]]

# %%
phase_diagram = []
T=146.6
phase_diagram.append([0.5, f1(0.5)]) #заношу в базу первую точку фазы
print(phase_diagram)

#T_start = T_krit2 - 1
T_start = 145
T_range = np.arange(T_start, 60.1, -1)

θ = np.arange(0.0001, 0.9999, 0.0002)

aP_fin = 0

#c = 0
#g = c+θ-θ

flag = False

for Ti in T_range: 
    print('-----------New--------------')
    T = Ti
    print('********* T ='+str(Ti)+' ********')
    
    max_x = opt.fminbound(f1_minus, 0, 0.5)
    min_x = opt.fminbound(f1, 0.5, 1)
    
    print('max_x: '+str(max_x) )
    print('min_x: '+str(min_x))
    
    h_maxi = 0.0002 #задаю шаг
    max_x = max_x + h_maxi
    min_x = min_x - h_maxi
    
    f_h_maxi = -f1(h_maxi)
    f_max_x = f1(max_x)
    f_min_x = f1 (min_x)
    
    print('f_max_x: '+str(f_max_x) )
    print('f_min_x: '+str(f_min_x))
    print('f_h_maxi: '+str(f_h_maxi))
    

    rng_line = np.arange(f_max_x, f_min_x, f_h_maxi) #диапазон max и min по оси Y 
    print(rng_line)
    print('Lenth: ' + str(len(rng_line)))
    
    span = np.arange(max_x, min_x, 0.0002) #диапазон max и min по оси X
    
    Si_old = 0
    Si_old_final = 0 
    Si_sum = 0
    aP = 0
    aP1_fin = 0
    aP2_fin = 0
    
    #Пробегаюсь по участкую от max до min
    for const in rng_line:
        
        f = θ*(1+2*θ*(np.exp(-(R*T)**(-1)*ε)-1)/(1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ)+((1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ))**2+4*(np.exp(-(R*T)**(-1)*ε)-1)*θ**2)**0.5))**z_1/(1-θ)
        f_c = lambda θ:  -c+θ*(1+2*θ*(sp.exp(-(R*T)**(-1)*ε)-1)/(1+(sp.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ)+((1+(sp.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ))**2+4*(sp.exp(-(R*T)**(-1)*ε)-1)*θ**2)**0.5))**z_1/(1-θ)

        print('---Start cycle inside---')
        c = const
        g = c+θ-θ
        print('c: ' + str(c))
        
        print('g: '+str(g))
        idθ = np.argwhere(np.diff(np.sign(f - g))).flatten()
        
        print('idθ: '+str(idθ))
        print('θ[idθ]: '+str(θ[idθ]))

        Si_old_final = Si_old
        
        print('Si_old_final: '+ str(Si_old_final))
        
        Si_c = ig.quad(f_c, a=0.1, b=0.9)
        print('Si_c: ' + str(Si_c))
                
        
        Si = ig.quad(f_c, a=θ[idθ[0]], b=θ[idθ[2]])
        Si_old = Si[0]

        print('Si: ' + str(Si[0]))
        
        if Si[0] < 0:
            print('continue')
        else:
            print('search aP')
            aP = c
            print('aP: ' + str(aP))
            if abs(Si[0])<abs(Si_old_final):
                aP1_fin = c
                aP_fin = aP1_fin
                print('aP1_fin: ' + str(aP1_fin))
                flag == True
                print('Flag1 == True')
                print('break')
                break
            else:
                aP2_fin = c - f_h_maxi
                aP_fin = aP2_fin
                print('aP2_fin: ' + str(aP2_fin))
                flag == True
                print('Flag2 == True')
                print('break')
                break
        print('end inside')
    print('----------------------------------------')
    print('-----!Si_old_final: '+ str(Si_old_final))
    print('-----!Si: ' + str(Si[0]))
    print('-----!aP_fin: ' + str(aP_fin))
    print('----------------------------------------')
    #далее ищу точки пересечения найденной прямой с графиком
    
    for i in 0, 2:
        phase_diagram.append([θ[idθ[i]], f[idθ[i]]])
    print('End')
plt.scatter(*zip(*phase_diagram))
# Out:
# [[0.5, 0.08758042042172726]]
# -----------New--------------
# ********* T =145.0 ********
# max_x: 0.4341479578676005
# min_x: 0.5658548824728018
# f_max_x: 0.08540498407170649
# f_min_x: 0.0851120110169682
# f_h_maxi: -0.00019973500024608759
# [0.08540498 0.08520525]
# Lenth: 2
# ---Start cycle inside---
# c: 0.08540498407170649
# g: [0.08540498 0.08540498 0.08540498 ... 0.08540498 0.08540498 0.08540498]
# idθ: [2169 2171 3148]
# θ[idθ]: [0.4339 0.4343 0.6297]
# Si_old_final: 0
# Si_c: (0.00036305995115746593, 3.3181534434665875e-11)
# Si: -3.2252391154928626e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.0852052490714604
# g: [0.08520525 0.08520525 0.08520525 ... 0.08520525 0.08520525 0.08520525]
# idθ: [1899 2581 3020]
# θ[idθ]: [0.3799 0.5163 0.6041]
# Si_old_final: -3.2252391154928626e-05
# Si_c: (0.0005228479513543355, 3.318153415991941e-11)
# Si: 1.1984608387695756e-05
# search aP
# aP: 0.0852052490714604
# aP1_fin: 0.0852052490714604
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -3.2252391154928626e-05
# -----!Si: 1.1984608387695756e-05
# -----!aP_fin: 0.0852052490714604
# ----------------------------------------
# End
# -----------New--------------
# ********* T =144.0 ********
# max_x: 0.4174221060722178
# min_x: 0.5825777651530841
# f_max_x: 0.08409997548749093
# f_min_x: 0.08352708488668927
# f_h_maxi: -0.0001997318901436526
# [0.08409998 0.08390024 0.08370051]
# Lenth: 3
# ---Start cycle inside---
# c: 0.08409997548749093
# g: [0.08409998 0.08409998 0.08409998 ... 0.08409998 0.08409998 0.08409998]
# idθ: [2085 2087 3306]
# θ[idθ]: [0.4171 0.4175 0.6613]
# Si_old_final: 0
# Si_c: (0.0002022464869349868, 3.241988960916421e-11)
# Si: -7.867431165577406e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08390024359734728
# g: [0.08390024 0.08390024 0.08390024 ... 0.08390024 0.08390024 0.08390024]
# idθ: [1838 2413 3239]
# θ[idθ]: [0.3677 0.4827 0.6479]
# Si_old_final: -7.867431165577406e-05
# Si_c: (0.0003620319990499054, 3.2419888587072204e-11)
# Si: -2.4449435674679323e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08370051170720363
# g: [0.08370051 0.08370051 0.08370051 ... 0.08370051 0.08370051 0.08370051]
# idθ: [1749 2611 3145]
# θ[idθ]: [0.3499 0.5223 0.6291]
# Si_old_final: -2.4449435674679323e-05
# Si_c: (0.0005218175111648237, 3.2419888788562764e-11)
# Si: 3.16744501836144e-05
# search aP
# aP: 0.08370051170720363
# aP2_fin: 0.08390024359734728
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -2.4449435674679323e-05
# -----!Si: 3.16744501836144e-05
# -----!aP_fin: 0.08390024359734728
# ----------------------------------------
# End
# -----------New--------------
# ********* T =143.0 ********
# max_x: 0.4035652760287722
# min_x: 0.5964346177200278
# f_max_x: 0.08282608021439085
# f_min_x: 0.08192142652428566
# f_h_maxi: -0.00019972871846714205
# [0.08282608 0.08262635 0.08242662 0.08222689 0.08202717]
# Lenth: 5
# ---Start cycle inside---
# c: 0.08282608021439085
# g: [0.08282608 0.08282608 0.08282608 ... 0.08282608 0.08282608 0.08282608]
# idθ: [2016 2018 3434]
# θ[idθ]: [0.4033 0.4037 0.6869]
# Si_old_final: 0
# Si_c: (2.3740569488392167e-05, 3.16824312261688e-11)
# Si: -0.0001443435851658922
# continue
# end inside
# ---Start cycle inside---
# c: 0.0826263514959237
# g: [0.08262635 0.08262635 0.08262635 ... 0.08262635 0.08262635 0.08262635]
# idθ: [1785 2307 3388]
# θ[idθ]: [0.3571 0.4615 0.6777]
# Si_old_final: -0.0001443435851658922
# Si_c: (0.00018352354426210684, 3.16824306374201e-11)
# Si: -8.230839579884934e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08242662277745656
# g: [0.08242662 0.08242662 0.08242662 ... 0.08242662 0.08242662 0.08242662]
# idθ: [1700 2460 3334]
# θ[idθ]: [0.3401 0.4921 0.6669]
# Si_old_final: -8.230839579884934e-05
# Si_c: (0.00034330651903582087, 3.168243033915059e-11)
# Si: -1.748661093049822e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08222689405898942
# g: [0.08222689 0.08222689 0.08222689 ... 0.08222689 0.08222689 0.08222689]
# idθ: [1638 2605 3264]
# θ[idθ]: [0.3277 0.5211 0.6529]
# Si_old_final: -1.748661093049822e-05
# Si_c: (0.0005030894938095351, 3.168243016050595e-11)
# Si: 4.774813431125603e-05
# search aP
# aP: 0.08222689405898942
# aP2_fin: 0.08242662277745656
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.748661093049822e-05
# -----!Si: 4.774813431125603e-05
# -----!aP_fin: 0.08242662277745656
# ----------------------------------------
# End
# -----------New--------------
# ********* T =142.0 ********
# max_x: 0.3914713536643228
# min_x: 0.608528691284826
# f_max_x: 0.08157863726088499
# f_min_x: 0.08030036082778032
# f_h_maxi: -0.0001997254834242651
# [0.08157864 0.08137891 0.08117919 0.08097946 0.08077974 0.08058001
#  0.08038028]
# Lenth: 7
# ---Start cycle inside---
# c: 0.08157863726088499
# g: [0.08157864 0.08157864 0.08157864 ... 0.08157864 0.08157864 0.08157864]
# idθ: [1955 1957 3542]
# θ[idθ]: [0.3911 0.3915 0.7085]
# Si_old_final: 0
# Si_c: (-0.0001686105040414321, 3.096999595885783e-11)
# Si: -0.0002283865434331342
# continue
# end inside
# ---Start cycle inside---
# c: 0.08137891177746072
# g: [0.08137891 0.08137891 0.08137891 ... 0.08137891 0.08137891 0.08137891]
# idθ: [1736 2224 3508]
# θ[idθ]: [0.3473 0.4449 0.7017]
# Si_old_final: -0.0002283865434331342
# Si_c: (-8.830117302015576e-06, 3.096999561046069e-11)
# Si: -0.00015972220921716594
# continue
# end inside
# ---Start cycle inside---
# c: 0.08117918629403645
# g: [0.08117919 0.08117919 0.08117919 ... 0.08117919 0.08117919 0.08117919]
# idθ: [1654 2357 3469]
# θ[idθ]: [0.3309 0.4715 0.6939]
# Si_old_final: -0.00015972220921716594
# Si_c: (0.00015095026943740117, 3.096999522624532e-11)
# Si: -8.795031453969973e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08097946081061218
# g: [0.08097946 0.08097946 0.08097946 ... 0.08097946 0.08097946 0.08097946]
# idθ: [1595 2475 3425]
# θ[idθ]: [0.3191 0.4951 0.6851]
# Si_old_final: -8.795031453969973e-05
# Si_c: (0.00031073065617681704, 3.0969995075241855e-11)
# Si: -1.5076537685446918e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08077973532718791
# g: [0.08077974 0.08077974 0.08077974 ... 0.08077974 0.08077974 0.08077974]
# idθ: [1547 2590 3371]
# θ[idθ]: [0.3095 0.5181 0.6743]
# Si_old_final: -1.5076537685446918e-05
# Si_c: (0.00047051104291623356, 3.096999500715241e-11)
# Si: 5.797102380856996e-05
# search aP
# aP: 0.08077973532718791
# aP2_fin: 0.08097946081061218
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.5076537685446918e-05
# -----!Si: 5.797102380856996e-05
# -----!aP_fin: 0.08097946081061218
# ----------------------------------------
# End
# -----------New--------------
# ********* T =141.0 ********
# max_x: 0.38060557314577803
# min_x: 0.6193944026090353
# f_max_x: 0.08035454974278661
# f_min_x: 0.07866765313312686
# f_h_maxi: -0.00019972218315413205
# [0.08035455 0.08015483 0.07995511 0.07975538 0.07955566 0.07935594
#  0.07915622 0.07895649 0.07875677]
# Lenth: 9
# ---Start cycle inside---
# c: 0.08035454974278661
# g: [0.08035455 0.08035455 0.08035455 ... 0.08035455 0.08035455 0.08035455]
# idθ: [1901 1903 3637]
# θ[idθ]: [0.3803 0.3807 0.7275]
# Si_old_final: 0
# Si_c: (-0.00037221021107052, 3.028356339142231e-11)
# Si: -0.0003299416693260009
# continue
# end inside
# ---Start cycle inside---
# c: 0.08015482755963248
# g: [0.08015483 0.08015483 0.08015483 ... 0.08015483 0.08015483 0.08015483]
# idθ: [1691 2153 3610]
# θ[idθ]: [0.3383 0.4307 0.7221]
# Si_old_final: -0.0003299416693260009
# Si_c: (-0.00021243246454721604, 3.028356277936303e-11)
# Si: -0.0002554427368140815
# continue
# end inside
# ---Start cycle inside---
# c: 0.07995510537647835
# g: [0.07995511 0.07995511 0.07995511 ... 0.07995511 0.07995511 0.07995511]
# idθ: [1612 2275 3580]
# θ[idθ]: [0.3225 0.4551 0.7161]
# Si_old_final: -0.0002554427368140815
# Si_c: (-5.265471802391188e-05, 3.028356239242513e-11)
# Si: -0.00017769780733188707
# continue
# end inside
# ---Start cycle inside---
# c: 0.07975538319332422
# g: [0.07975538 0.07975538 0.07975538 ... 0.07975538 0.07975538 0.07975538]
# idθ: [1555 2378 3547]
# θ[idθ]: [0.3111 0.4757 0.7095]
# Si_old_final: -0.00017769780733188707
# Si_c: (0.00010712302849939207, 3.0283562177411616e-11)
# Si: -9.853859898189875e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07955566101017009
# g: [0.07955566 0.07955566 0.07955566 ... 0.07955566 0.07955566 0.07955566]
# idθ: [1508 2475 3510]
# θ[idθ]: [0.3017 0.4951 0.7021]
# Si_old_final: -9.853859898189875e-05
# Si_c: (0.00026690077502269645, 3.028356229290967e-11)
# Si: -1.8714801606451994e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07935593882701596
# g: [0.07935594 0.07935594 0.07935594 ... 0.07935594 0.07935594 0.07935594]
# idθ: [1468 2572 3467]
# θ[idθ]: [0.2937 0.5145 0.6935]
# Si_old_final: -1.8714801606451994e-05
# Si_c: (0.0004266785215460004, 3.028356208295233e-11)
# Si: 6.123283303430049e-05
# search aP
# aP: 0.07935593882701596
# aP2_fin: 0.07955566101017009
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.8714801606451994e-05
# -----!Si: 6.123283303430049e-05
# -----!aP_fin: 0.07955566101017009
# ----------------------------------------
# End
# -----------New--------------
# ********* T =140.0 ********
# max_x: 0.3706570987137918
# min_x: 0.6293428582524709
# f_max_x: 0.07915155746732655
# f_min_x: 0.07702623625783676
# f_h_maxi: -0.00019971881572400322
# [0.07915156 0.07895184 0.07875212 0.0785524  0.07835268 0.07815296
#  0.07795324 0.07775353 0.07755381 0.07735409 0.07715437]
# Lenth: 11
# ---Start cycle inside---
# c: 0.07915155746732655
# g: [0.07915156 0.07915156 0.07915156 ... 0.07915156 0.07915156 0.07915156]
# idθ: [1851 1853 3722]
# θ[idθ]: [0.3703 0.3707 0.7445]
# Si_old_final: 0
# Si_c: (-0.0005851309018399711, 2.9624315147223563e-11)
# Si: -0.00044815767866361025
# continue
# end inside
# ---Start cycle inside---
# c: 0.07895183865160255
# g: [0.07895184 0.07895184 0.07895184 ... 0.07895184 0.07895184 0.07895184]
# idθ: [1649 2091 3700]
# θ[idθ]: [0.3299 0.4183 0.7401]
# Si_old_final: -0.00044815767866361025
# Si_c: (-0.0004253558492607677, 2.962431438036251e-11)
# Si: -0.0003684134084596468
# continue
# end inside
# ---Start cycle inside---
# c: 0.07875211983587854
# g: [0.07875212 0.07875212 0.07875212 ... 0.07875212 0.07875212 0.07875212]
# idθ: [1573 2204 3676]
# θ[idθ]: [0.3147 0.4409 0.7353]
# Si_old_final: -0.0003684134084596468
# Si_c: (-0.0002655807966815643, 2.962431412668076e-11)
# Si: -0.00028536403948761085
# continue
# end inside
# ---Start cycle inside---
# c: 0.07855240102015454
# g: [0.0785524 0.0785524 0.0785524 ... 0.0785524 0.0785524 0.0785524]
# idθ: [1517 2299 3650]
# θ[idθ]: [0.3035 0.4599 0.7301]
# Si_old_final: -0.00028536403948761085
# Si_c: (-0.0001058057441023618, 2.962431384089591e-11)
# Si: -0.00020073183139098202
# continue
# end inside
# ---Start cycle inside---
# c: 0.07835268220443053
# g: [0.07835268 0.07835268 0.07835268 ... 0.07835268 0.07835268 0.07835268]
# idθ: [1472 2386 3621]
# θ[idθ]: [0.2945 0.4773 0.7243]
# Si_old_final: -0.00020073183139098202
# Si_c: (5.396930847684114e-05, 2.962431384395404e-11)
# Si: -0.0001151822633023701
# continue
# end inside
# ---Start cycle inside---
# c: 0.07815296338870653
# g: [0.07815296 0.07815296 0.07815296 ... 0.07815296 0.07815296 0.07815296]
# idθ: [1433 2469 3590]
# θ[idθ]: [0.2867 0.4939 0.7181]
# Si_old_final: -0.0001151822633023701
# Si_c: (0.0002137443610560441, 2.962431372154382e-11)
# Si: -2.9155013022631216e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07795324457298253
# g: [0.07795324 0.07795324 0.07795324 ... 0.07795324 0.07795324 0.07795324]
# idθ: [1399 2552 3554]
# θ[idθ]: [0.2799 0.5105 0.7109]
# Si_old_final: -2.9155013022631216e-05
# Si_c: (0.00037351941363524726, 2.9624313658990145e-11)
# Si: 5.6994045079043014e-05
# search aP
# aP: 0.07795324457298253
# aP2_fin: 0.07815296338870653
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -2.9155013022631216e-05
# -----!Si: 5.6994045079043014e-05
# -----!aP_fin: 0.07815296338870653
# ----------------------------------------
# End
# -----------New--------------
# ********* T =139.0 ********
# max_x: 0.36142814828225295
# min_x: 0.6385719278939289
# f_max_x: 0.07796791253510539
# f_min_x: 0.0753785344991957
# f_h_maxi: -0.00019971537912585565
# [0.07796791 0.0777682  0.07756848 0.07736877 0.07716905 0.07696934
#  0.07676962 0.0765699  0.07637019 0.07617047 0.07597076 0.07577104
#  0.07557133]
# Lenth: 13
# ---Start cycle inside---
# c: 0.07796791253510539
# g: [0.07796791 0.07796791 0.07796791 ... 0.07796791 0.07796791 0.07796791]
# idθ: [1805 1807 3799]
# θ[idθ]: [0.3611 0.3615 0.7599]
# Si_old_final: 0
# Si_c: (-0.0008058543133630186, 2.897809699095717e-11)
# Si: -0.0005821929621884178
# continue
# end inside
# ---Start cycle inside---
# c: 0.07776819715597953
# g: [0.0777682 0.0777682 0.0777682 ... 0.0777682 0.0777682 0.0777682]
# idθ: [1610 2034 3780]
# θ[idθ]: [0.3221 0.4069 0.7561]
# Si_old_final: -0.0005821929621884178
# Si_c: (-0.0006460820100623318, 2.8978096295355345e-11)
# Si: -0.0004976652445615742
# continue
# end inside
# ---Start cycle inside---
# c: 0.07756848177685367
# g: [0.07756848 0.07756848 0.07756848 ... 0.07756848 0.07756848 0.07756848]
# idθ: [1536 2141 3760]
# θ[idθ]: [0.3073 0.4283 0.7521]
# Si_old_final: -0.0004976652445615742
# Si_c: (-0.00048630970676164485, 2.897809634858499e-11)
# Si: -0.00040981397337506135
# continue
# end inside
# ---Start cycle inside---
# c: 0.07736876639772781
# g: [0.07736877 0.07736877 0.07736877 ... 0.07736877 0.07736877 0.07736877]
# idθ: [1482 2230 3738]
# θ[idθ]: [0.2965 0.4461 0.7477]
# Si_old_final: -0.00040981397337506135
# Si_c: (-0.000326537403460958, 2.8978096348584992e-11)
# Si: -0.0003202800098686957
# continue
# end inside
# ---Start cycle inside---
# c: 0.07716905101860196
# g: [0.07716905 0.07716905 0.07716905 ... 0.07716905 0.07716905 0.07716905]
# idθ: [1437 2311 3715]
# θ[idθ]: [0.2875 0.4623 0.7431]
# Si_old_final: -0.0003202800098686957
# Si_c: (-0.00016676510016027063, 2.8978096346371208e-11)
# Si: -0.00022968207060732098
# continue
# end inside
# ---Start cycle inside---
# c: 0.0769693356394761
# g: [0.07696934 0.07696934 0.07696934 ... 0.07696934 0.07696934 0.07696934]
# idθ: [1400 2386 3691]
# θ[idθ]: [0.2801 0.4773 0.7383]
# Si_old_final: -0.00022968207060732098
# Si_c: (-6.992796859583679e-06, 2.897809634858499e-11)
# Si: -0.0001384063425071676
# continue
# end inside
# ---Start cycle inside---
# c: 0.07676962026035024
# g: [0.07676962 0.07676962 0.07676962 ... 0.07676962 0.07676962 0.07676962]
# idθ: [1366 2460 3664]
# θ[idθ]: [0.2733 0.4921 0.7329]
# Si_old_final: -0.0001384063425071676
# Si_c: (0.00015277950644110349, 2.897809634858499e-11)
# Si: -4.674706779908223e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07656990488122438
# g: [0.0765699 0.0765699 0.0765699 ... 0.0765699 0.0765699 0.0765699]
# idθ: [1336 2533 3634]
# θ[idθ]: [0.2673 0.5067 0.7269]
# Si_old_final: -4.674706779908223e-05
# Si_c: (0.00031255180974179043, 2.8978096221164352e-11)
# Si: 4.504266712760498e-05
# search aP
# aP: 0.07656990488122438
# aP1_fin: 0.07656990488122438
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -4.674706779908223e-05
# -----!Si: 4.504266712760498e-05
# -----!aP_fin: 0.07656990488122438
# ----------------------------------------
# End
# -----------New--------------
# ********* T =138.0 ********
# max_x: 0.3527849481720895
# min_x: 0.6472152581106354
# f_max_x: 0.0768022088563015
# f_min_x: 0.0737266336730937
# f_h_maxi: -0.00019971187127275318
# [0.07680221 0.0766025  0.07640279 0.07620307 0.07600336 0.07580365
#  0.07560394 0.07540423 0.07520451 0.0750048  0.07480509 0.07460538
#  0.07440567 0.07420595 0.07400624 0.07380653]
# Lenth: 16
# ---Start cycle inside---
# c: 0.0768022088563015
# g: [0.07680221 0.07680221 0.07680221 ... 0.07680221 0.07680221 0.07680221]
# idθ: [1762 1764 3869]
# θ[idθ]: [0.3525 0.3529 0.7739]
# Si_old_final: 0
# Si_c: (-0.0010331352161889267, 2.8311991102738843e-11)
# Si: -0.0007312155175746175
# continue
# end inside
# ---Start cycle inside---
# c: 0.07660249698502875
# g: [0.0766025 0.0766025 0.0766025 ... 0.0766025 0.0766025 0.0766025]
# idθ: [1573 1983 3852]
# θ[idθ]: [0.3147 0.3967 0.7705]
# Si_old_final: -0.0007312155175746175
# Si_c: (-0.0008733657191707239, 2.8311990911782476e-11)
# Si: -0.0006422806618642587
# continue
# end inside
# ---Start cycle inside---
# c: 0.07640278511375599
# g: [0.07640279 0.07640279 0.07640279 ... 0.07640279 0.07640279 0.07640279]
# idθ: [1501 2085 3835]
# θ[idθ]: [0.3003 0.4171 0.7671]
# Si_old_final: -0.0006422806618642587
# Si_c: (-0.000713596222152521, 2.8311991167963233e-11)
# Si: -0.0005500265983757389
# continue
# end inside
# ---Start cycle inside---
# c: 0.07620307324248324
# g: [0.07620307 0.07620307 0.07620307 ... 0.07620307 0.07620307 0.07620307]
# idθ: [1448 2169 3817]
# θ[idθ]: [0.2897 0.4339 0.7635]
# Si_old_final: -0.0005500265983757389
# Si_c: (-0.0005538267251343181, 2.8311991039872855e-11)
# Si: -0.0004560304511106817
# continue
# end inside
# ---Start cycle inside---
# c: 0.07600336137121048
# g: [0.07600336 0.07600336 0.07600336 ... 0.07600336 0.07600336 0.07600336]
# idθ: [1405 2244 3798]
# θ[idθ]: [0.2811 0.4489 0.7597]
# Si_old_final: -0.0004560304511106817
# Si_c: (-0.00039405722811611536, 2.831199104105209e-11)
# Si: -0.0003608755399567274
# continue
# end inside
# ---Start cycle inside---
# c: 0.07580364949993773
# g: [0.07580365 0.07580365 0.07580365 ... 0.07580365 0.07580365 0.07580365]
# idθ: [1368 2315 3778]
# θ[idθ]: [0.2737 0.4631 0.7557]
# Si_old_final: -0.0003608755399567274
# Si_c: (-0.00023428773109791248, 2.831199110509729e-11)
# Si: -0.0002649183653601546
# continue
# end inside
# ---Start cycle inside---
# c: 0.07560393762866498
# g: [0.07560394 0.07560394 0.07560394 ... 0.07560394 0.07560394 0.07560394]
# idθ: [1335 2382 3756]
# θ[idθ]: [0.2671 0.4765 0.7513]
# Si_old_final: -0.0002649183653601546
# Si_c: (-7.451823407970937e-05, 2.8311991103918053e-11)
# Si: -0.00016841883546434307
# continue
# end inside
# ---Start cycle inside---
# c: 0.07540422575739222
# g: [0.07540423 0.07540423 0.07540423 ... 0.07540423 0.07540423 0.07540423]
# idθ: [1306 2448 3733]
# θ[idθ]: [0.2613 0.4897 0.7467]
# Si_old_final: -0.00016841883546434307
# Si_c: (8.525126293849341e-05, 2.8311991103918053e-11)
# Si: -7.158988649612901e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07520451388611947
# g: [0.07520451 0.07520451 0.07520451 ... 0.07520451 0.07520451 0.07520451]
# idθ: [1279 2513 3707]
# θ[idθ]: [0.2559 0.5027 0.7415]
# Si_old_final: -7.158988649612901e-05
# Si_c: (0.0002450207599566963, 2.8311991488189176e-11)
# Si: 2.53797939155958e-05
# search aP
# aP: 0.07520451388611947
# aP1_fin: 0.07520451388611947
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -7.158988649612901e-05
# -----!Si: 2.53797939155958e-05
# -----!aP_fin: 0.07520451388611947
# ----------------------------------------
# End
# -----------New--------------
# ********* T =137.0 ********
# max_x: 0.3446290416289224
# min_x: 0.6553710117373452
# f_max_x: 0.07565328266732683
# f_min_x: 0.07207238013342743
# f_h_maxi: -0.00019970828999500833
# [0.07565328 0.07545357 0.07525387 0.07505416 0.07485445 0.07465474
#  0.07445503 0.07425532 0.07405562 0.07385591 0.0736562  0.07345649
#  0.07325678 0.07305707 0.07285737 0.07265766 0.07245795 0.07225824]
# Lenth: 18
# ---Start cycle inside---
# c: 0.07565328266732683
# g: [0.07565328 0.07565328 0.07565328 ... 0.07565328 0.07565328 0.07565328]
# idθ: [1721 1723 3933]
# θ[idθ]: [0.3443 0.3447 0.7867]
# Si_old_final: 0
# Si_c: (-0.00126592186296985, 2.7673747560571743e-11)
# Si: -0.0008944029798860941
# continue
# end inside
# ---Start cycle inside---
# c: 0.07545357437733183
# g: [0.07545357 0.07545357 0.07545357 ... 0.07545357 0.07545357 0.07545357]
# idθ: [1537 1934 3919]
# θ[idθ]: [0.3075 0.3869 0.7839]
# Si_old_final: -0.0008944029798860941
# Si_c: (-0.0011061552309738444, 2.7673747591819786e-11)
# Si: -0.0008013782155389733
# continue
# end inside
# ---Start cycle inside---
# c: 0.07525386608733682
# g: [0.07525387 0.07525387 0.07525387 ... 0.07525387 0.07525387 0.07525387]
# idθ: [1467 2033 3904]
# θ[idθ]: [0.2935 0.4067 0.7809]
# Si_old_final: -0.0008013782155389733
# Si_c: (-0.0009463885989778386, 2.767374752680898e-11)
# Si: -0.0007050495191322872
# continue
# end inside
# ---Start cycle inside---
# c: 0.07505415779734181
# g: [0.07505416 0.07505416 0.07505416 ... 0.07505416 0.07505416 0.07505416]
# idθ: [1415 2113 3888]
# θ[idθ]: [0.2831 0.4227 0.7777]
# Si_old_final: -0.0007050495191322872
# Si_c: (-0.0007866219669818331, 2.7673747591819786e-11)
# Si: -0.0006069420242107073
# continue
# end inside
# ---Start cycle inside---
# c: 0.0748544495073468
# g: [0.07485445 0.07485445 0.07485445 ... 0.07485445 0.07485445 0.07485445]
# idθ: [1373 2184 3872]
# θ[idθ]: [0.2747 0.4369 0.7745]
# Si_old_final: -0.0006069420242107073
# Si_c: (-0.0006268553349858272, 2.7673747655573265e-11)
# Si: -0.0005076150498259666
# continue
# end inside
# ---Start cycle inside---
# c: 0.0746547412173518
# g: [0.07465474 0.07465474 0.07465474 ... 0.07465474 0.07465474 0.07465474]
# idθ: [1337 2251 3855]
# θ[idθ]: [0.2675 0.4503 0.7711]
# Si_old_final: -0.0005076150498259666
# Si_c: (-0.0004670887029898219, 2.7673747460540843e-11)
# Si: -0.00040740235954352864
# continue
# end inside
# ---Start cycle inside---
# c: 0.07445503292735679
# g: [0.07445503 0.07445503 0.07445503 ... 0.07445503 0.07445503 0.07445503]
# idθ: [1305 2314 3837]
# θ[idθ]: [0.2611 0.4629 0.7675]
# Si_old_final: -0.00040740235954352864
# Si_c: (-0.00030732207099381614, 2.7673747656830596e-11)
# Si: -0.00030654370722017977
# continue
# end inside
# ---Start cycle inside---
# c: 0.07425532463736179
# g: [0.07425532 0.07425532 0.07425532 ... 0.07425532 0.07425532 0.07425532]
# idθ: [1277 2375 3818]
# θ[idθ]: [0.2555 0.4751 0.7637]
# Si_old_final: -0.00030654370722017977
# Si_c: (-0.0001475554389978105, 2.7673747655573265e-11)
# Si: -0.00020522767235456505
# continue
# end inside
# ---Start cycle inside---
# c: 0.07405561634736678
# g: [0.07405562 0.07405562 0.07405562 ... 0.07405562 0.07405562 0.07405562]
# idθ: [1251 2435 3797]
# θ[idθ]: [0.2503 0.4871 0.7595]
# Si_old_final: -0.00020522767235456505
# Si_c: (1.2211192998194936e-05, 2.7673747526180313e-11)
# Si: -0.00010361608679627562
# continue
# end inside
# ---Start cycle inside---
# c: 0.07385590805737177
# g: [0.07385591 0.07385591 0.07385591 ... 0.07385591 0.07385591 0.07385591]
# idθ: [1226 2495 3775]
# θ[idθ]: [0.2453 0.4991 0.7551]
# Si_old_final: -0.00010361608679627562
# Si_c: (0.0001719778249942007, 2.7673747654944608e-11)
# Si: -1.8560771106392563e-06
# continue
# end inside
# ---Start cycle inside---
# c: 0.07365619976737676
# g: [0.0736562 0.0736562 0.0736562 ... 0.0736562 0.0736562 0.0736562]
# idθ: [1204 2554 3751]
# θ[idθ]: [0.2409 0.5109 0.7503]
# Si_old_final: -1.8560771106392563e-06
# Si_c: (0.00033174445699020634, 2.7673747657459272e-11)
# Si: 9.991559533423309e-05
# search aP
# aP: 0.07365619976737676
# aP2_fin: 0.07385590805737177
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.8560771106392563e-06
# -----!Si: 9.991559533423309e-05
# -----!aP_fin: 0.07385590805737177
# ----------------------------------------
# End
# -----------New--------------
# ********* T =136.0 ********
# max_x: 0.3368847655492829
# min_x: 0.6631152662309869
# f_max_x: 0.07452014967309861
# f_min_x: 0.07041744309533149
# f_h_maxi: -0.00019970463303612215
# [0.07452015 0.07432045 0.07412074 0.07392104 0.07372133 0.07352163
#  0.07332192 0.07312222 0.07292251 0.07272281 0.0725231  0.0723234
#  0.07212369 0.07192399 0.07172428 0.07152458 0.07132488 0.07112517
#  0.07092547 0.07072576 0.07052606]
# Lenth: 21
# ---Start cycle inside---
# c: 0.07452014967309861
# g: [0.07452015 0.07452015 0.07452015 ... 0.07452015 0.07452015 0.07452015]
# idθ: [1682 1684 3992]
# θ[idθ]: [0.3365 0.3369 0.7985]
# Si_old_final: 0
# Si_c: (-0.001503305738994774, 2.706485155336986e-11)
# Si: -0.0010709416654421247
# continue
# end inside
# ---Start cycle inside---
# c: 0.0743204450400625
# g: [0.07432045 0.07432045 0.07432045 ... 0.07432045 0.07432045 0.07432045]
# idθ: [1503 1889 3980]
# θ[idθ]: [0.3007 0.3779 0.7961]
# Si_old_final: -0.0010709416654421247
# Si_c: (-0.001343542032565879, 2.706485153685382e-11)
# Si: -0.0009740964927364563
# continue
# end inside
# ---Start cycle inside---
# c: 0.07412074040702638
# g: [0.07412074 0.07412074 0.07412074 ... 0.07412074 0.07412074 0.07412074]
# idθ: [1434 1984 3967]
# θ[idθ]: [0.2869 0.3969 0.7935]
# Si_old_final: -0.0009740964927364563
# Si_c: (-0.0011837783261369843, 2.7064851622116025e-11)
# Si: -0.0008739716047827078
# continue
# end inside
# ---Start cycle inside---
# c: 0.07392103577399026
# g: [0.07392104 0.07392104 0.07392104 ... 0.07392104 0.07392104 0.07392104]
# idθ: [1384 2061 3953]
# θ[idθ]: [0.2769 0.4123 0.7907]
# Si_old_final: -0.0008739716047827078
# Si_c: (-0.0010240146197080893, 2.7064851571226898e-11)
# Si: -0.0007720461649805322
# continue
# end inside
# ---Start cycle inside---
# c: 0.07372133114095414
# g: [0.07372133 0.07372133 0.07372133 ... 0.07372133 0.07372133 0.07372133]
# idθ: [1343 2130 3939]
# θ[idθ]: [0.2687 0.4261 0.7879]
# Si_old_final: -0.0007720461649805322
# Si_c: (-0.0008642509132791945, 2.7064851488646717e-11)
# Si: -0.000668859780901536
# continue
# end inside
# ---Start cycle inside---
# c: 0.07352162650791802
# g: [0.07352163 0.07352163 0.07352163 ... 0.07352163 0.07352163 0.07352163]
# idθ: [1308 2193 3924]
# θ[idθ]: [0.2617 0.4387 0.7849]
# Si_old_final: -0.000668859780901536
# Si_c: (-0.0007044872068502996, 2.706485165246606e-11)
# Si: -0.0005647300694300862
# continue
# end inside
# ---Start cycle inside---
# c: 0.0733219218748819
# g: [0.07332192 0.07332192 0.07332192 ... 0.07332192 0.07332192 0.07332192]
# idθ: [1276 2253 3909]
# θ[idθ]: [0.2553 0.4507 0.7819]
# Si_old_final: -0.0005647300694300862
# Si_c: (-0.000544723500421405, 2.7064851487305715e-11)
# Si: -0.00045988450905610345
# continue
# end inside
# ---Start cycle inside---
# c: 0.07312221724184578
# g: [0.07312222 0.07312222 0.07312222 ... 0.07312222 0.07312222 0.07312222]
# idθ: [1248 2310 3893]
# θ[idθ]: [0.2497 0.4621 0.7787]
# Si_old_final: -0.00045988450905610345
# Si_c: (-0.0003849597939925103, 2.7064851389550515e-11)
# Si: -0.0003544939859059706
# continue
# end inside
# ---Start cycle inside---
# c: 0.07292251260880966
# g: [0.07292251 0.07292251 0.07292251 ... 0.07292251 0.07292251 0.07292251]
# idθ: [1223 2366 3875]
# θ[idθ]: [0.2447 0.4733 0.7751]
# Si_old_final: -0.0003544939859059706
# Si_c: (-0.00022519608756361537, 2.7064851456285156e-11)
# Si: -0.00024870253038670597
# continue
# end inside
# ---Start cycle inside---
# c: 0.07272280797577355
# g: [0.07272281 0.07272281 0.07272281 ... 0.07272281 0.07272281 0.07272281]
# idθ: [1199 2421 3857]
# θ[idθ]: [0.2399 0.4843 0.7715]
# Si_old_final: -0.00024870253038670597
# Si_c: (-6.54323811347206e-05, 2.7064851523019817e-11)
# Si: -0.00014264094207370876
# continue
# end inside
# ---Start cycle inside---
# c: 0.07252310334273743
# g: [0.0725231 0.0725231 0.0725231 ... 0.0725231 0.0725231 0.0725231]
# idθ: [1177 2476 3838]
# θ[idθ]: [0.2355 0.4953 0.7677]
# Si_old_final: -0.00014264094207370876
# Si_c: (9.433132529417421e-05, 2.7064851456285156e-11)
# Si: -3.642256314426512e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07232339870970131
# g: [0.0723234 0.0723234 0.0723234 ... 0.0723234 0.0723234 0.0723234]
# idθ: [1157 2531 3817]
# θ[idθ]: [0.2315 0.5063 0.7635]
# Si_old_final: -3.642256314426512e-05
# Si_c: (0.000254095031723069, 2.7064851653807062e-11)
# Si: 6.984292050033934e-05
# search aP
# aP: 0.07232339870970131
# aP2_fin: 0.07252310334273743
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -3.642256314426512e-05
# -----!Si: 6.984292050033934e-05
# -----!aP_fin: 0.07252310334273743
# ----------------------------------------
# End
# -----------New--------------
# ********* T =135.0 ********
# max_x: 0.3295005458477885
# min_x: 0.6704994686446191
# f_max_x: 0.07340196261806248
# f_min_x: 0.0687633565752531
# f_h_maxi: -0.0001997008980484863
# [0.07340196 0.07320226 0.07300256 0.07280286 0.07260316 0.07240346
#  0.07220376 0.07200406 0.07180436 0.07160465 0.07140495 0.07120525
#  0.07100555 0.07080585 0.07060615 0.07040645 0.07020675 0.07000705
#  0.06980735 0.06960765 0.06940794 0.06920824 0.06900854 0.06880884]
# Lenth: 24
# ---Start cycle inside---
# c: 0.07340196261806248
# g: [0.07340196 0.07340196 0.07340196 ... 0.07340196 0.07340196 0.07340196]
# idθ: [1646 1648 4047]
# θ[idθ]: [0.3293 0.3297 0.8095]
# Si_old_final: 0
# Si_c: (-0.0017444876572297345, 2.6487056465134826e-11)
# Si: -0.001260027797748667
# continue
# end inside
# ---Start cycle inside---
# c: 0.073202261720014
# g: [0.07320226 0.07320226 0.07320226 ... 0.07320226 0.07320226 0.07320226]
# idθ: [1470 1847 4036]
# θ[idθ]: [0.2941 0.3695 0.8073]
# Si_old_final: -0.001260027797748667
# Si_c: (-0.0015847269387909504, 2.6487056565961238e-11)
# Si: -0.0011595956809483162
# continue
# end inside
# ---Start cycle inside---
# c: 0.07300256082196552
# g: [0.07300256 0.07300256 0.07300256 ... 0.07300256 0.07300256 0.07300256]
# idθ: [1403 1938 4025]
# θ[idθ]: [0.2807 0.3877 0.8051]
# Si_old_final: -0.0011595956809483162
# Si_c: (-0.0014249662203521666, 2.6487056567391236e-11)
# Si: -0.0010559143346264624
# continue
# end inside
# ---Start cycle inside---
# c: 0.07280285992391704
# g: [0.07280286 0.07280286 0.07280286 ... 0.07280286 0.07280286 0.07280286]
# idθ: [1354 2013 4013]
# θ[idθ]: [0.2709 0.4027 0.8027]
# Si_old_final: -0.0010559143346264624
# Si_c: (-0.0012652055019133825, 2.648705643152603e-11)
# Si: -0.0009504216376490246
# continue
# end inside
# ---Start cycle inside---
# c: 0.07260315902586856
# g: [0.07260316 0.07260316 0.07260316 ... 0.07260316 0.07260316 0.07260316]
# idθ: [1314 2079 4001]
# θ[idθ]: [0.2629 0.4159 0.8003]
# Si_old_final: -0.0009504216376490246
# Si_c: (-0.0011054447834745987, 2.6487056567391236e-11)
# Si: -0.0008436394961202844
# continue
# end inside
# ---Start cycle inside---
# c: 0.07240345812782008
# g: [0.07240346 0.07240346 0.07240346 ... 0.07240346 0.07240346 0.07240346]
# idθ: [1279 2139 3988]
# θ[idθ]: [0.2559 0.4279 0.7977]
# Si_old_final: -0.0008436394961202844
# Si_c: (-0.0009456840650358148, 2.6487056432956027e-11)
# Si: -0.0007358744830113198
# continue
# end inside
# ---Start cycle inside---
# c: 0.0722037572297716
# g: [0.07220376 0.07220376 0.07220376 ... 0.07220376 0.07220376 0.07220376]
# idθ: [1249 2197 3974]
# θ[idθ]: [0.2499 0.4395 0.7949]
# Si_old_final: -0.0007358744830113198
# Si_c: (-0.0007859233465970307, 2.6487056514118055e-11)
# Si: -0.0006273392758694303
# continue
# end inside
# ---Start cycle inside---
# c: 0.07200405633172312
# g: [0.07200406 0.07200406 0.07200406 ... 0.07200406 0.07200406 0.07200406]
# idθ: [1221 2251 3960]
# θ[idθ]: [0.2443 0.4503 0.7921]
# Si_old_final: -0.0006273392758694303
# Si_c: (-0.000626162628158247, 2.6487056482654233e-11)
# Si: -0.0005181999054728665
# continue
# end inside
# ---Start cycle inside---
# c: 0.07180435543367464
# g: [0.07180436 0.07180436 0.07180436 ... 0.07180436 0.07180436 0.07180436]
# idθ: [1196 2304 3945]
# θ[idθ]: [0.2393 0.4609 0.7891]
# Si_old_final: -0.0005181999054728665
# Si_c: (-0.0004664019097194628, 2.6487056566676235e-11)
# Si: -0.0004085872740445902
# continue
# end inside
# ---Start cycle inside---
# c: 0.07160465453562616
# g: [0.07160465 0.07160465 0.07160465 ... 0.07160465 0.07160465 0.07160465]
# idθ: [1173 2356 3930]
# θ[idθ]: [0.2347 0.4713 0.7861]
# Si_old_final: -0.0004085872740445902
# Si_c: (-0.0003066411912806789, 2.6487056499458624e-11)
# Si: -0.0002986181702403716
# continue
# end inside
# ---Start cycle inside---
# c: 0.07140495363757768
# g: [0.07140495 0.07140495 0.07140495 ... 0.07140495 0.07140495 0.07140495]
# idθ: [1152 2408 3914]
# θ[idθ]: [0.2305 0.4817 0.7829]
# Si_old_final: -0.0002986181702403716
# Si_c: (-0.00014688047284189493, 2.6487056599570032e-11)
# Si: -0.00018839247639066792
# continue
# end inside
# ---Start cycle inside---
# c: 0.0712052527395292
# g: [0.07120525 0.07120525 0.07120525 ... 0.07120525 0.07120525 0.07120525]
# idθ: [1131 2458 3896]
# θ[idθ]: [0.2263 0.4917 0.7793]
# Si_old_final: -0.00018839247639066792
# Si_c: (1.2880245596888853e-05, 2.6487056397917234e-11)
# Si: -7.800516688464702e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07100555184148072
# g: [0.07100555 0.07100555 0.07100555 ... 0.07100555 0.07100555 0.07100555]
# idθ: [1112 2509 3878]
# θ[idθ]: [0.2225 0.5019 0.7757]
# Si_old_final: -7.800516688464702e-05
# Si_c: (0.00017264096403567296, 2.6487056666430133e-11)
# Si: 3.245247345935342e-05
# search aP
# aP: 0.07100555184148072
# aP1_fin: 0.07100555184148072
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -7.800516688464702e-05
# -----!Si: 3.245247345935342e-05
# -----!aP_fin: 0.07100555184148072
# ----------------------------------------
# End
# -----------New--------------
# ********* T =134.0 ********
# max_x: 0.3224298632025059
# min_x: 0.6775701278344032
# f_max_x: 0.07229798279627002
# f_min_x: 0.06711154734205842
# f_h_maxi: -0.0001996970825888307
# [0.07229798 0.07209829 0.07189859 0.07169889 0.07149919 0.0712995
#  0.0710998  0.0709001  0.07070041 0.07050071 0.07030101 0.07010131
#  0.06990162 0.06970192 0.06950222 0.06930253 0.06910283 0.06890313
#  0.06870344 0.06850374 0.06830404 0.06810434 0.06790465 0.06770495
#  0.06750525 0.06730556]
# Lenth: 26
# ---Start cycle inside---
# c: 0.07229798279627002
# g: [0.07229798 0.07229798 0.07229798 ... 0.07229798 0.07229798 0.07229798]
# idθ: [1610 1612 4099]
# θ[idθ]: [0.3221 0.3225 0.8199]
# Si_old_final: 0
# Si_c: (-0.0019887550061364746, 2.5942514953254625e-11)
# Si: -0.0014608679492544006
# continue
# end inside
# ---Start cycle inside---
# c: 0.07209828571368118
# g: [0.07209829 0.07209829 0.07209829 ... 0.07209829 0.07209829 0.07209829]
# idθ: [1439 1806 4089]
# θ[idθ]: [0.2879 0.3613 0.8179]
# Si_old_final: -0.0014608679492544006
# Si_c: (-0.0018289973400654048, 2.5942514883241202e-11)
# Si: -0.0013570550272413427
# continue
# end inside
# ---Start cycle inside---
# c: 0.07189858863109234
# g: [0.07189859 0.07189859 0.07189859 ... 0.07189859 0.07189859 0.07189859]
# idθ: [1373 1895 4079]
# θ[idθ]: [0.2747 0.3791 0.8159]
# Si_old_final: -0.0013570550272413427
# Si_c: (-0.001669239673994335, 2.5942514883241202e-11)
# Si: -0.0012500251850499895
# continue
# end inside
# ---Start cycle inside---
# c: 0.07169889154850351
# g: [0.07169889 0.07169889 0.07169889 ... 0.07169889 0.07169889 0.07169889]
# idθ: [1325 1967 4068]
# θ[idθ]: [0.2651 0.3935 0.8137]
# Si_old_final: -0.0012500251850499895
# Si_c: (-0.0015094820079232653, 2.5942514884768488e-11)
# Si: -0.0011411805797019987
# continue
# end inside
# ---Start cycle inside---
# c: 0.07149919446591467
# g: [0.07149919 0.07149919 0.07149919 ... 0.07149919 0.07149919 0.07149919]
# idθ: [1285 2031 4057]
# θ[idθ]: [0.2571 0.4063 0.8115]
# Si_old_final: -0.0011411805797019987
# Si_c: (-0.0013497243418521955, 2.5942514884768488e-11)
# Si: -0.0010310289252469726
# continue
# end inside
# ---Start cycle inside---
# c: 0.07129949738332583
# g: [0.0712995 0.0712995 0.0712995 ... 0.0712995 0.0712995 0.0712995]
# idθ: [1252 2090 4046]
# θ[idθ]: [0.2505 0.4181 0.8093]
# Si_old_final: -0.0010310289252469726
# Si_c: (-0.0011899666757811257, 2.5942514852052725e-11)
# Si: -0.0009198655993310824
# continue
# end inside
# ---Start cycle inside---
# c: 0.071099800300737
# g: [0.0710998 0.0710998 0.0710998 ... 0.0710998 0.0710998 0.0710998]
# idθ: [1222 2144 4034]
# θ[idθ]: [0.2445 0.4289 0.8069]
# Si_old_final: -0.0009198655993310824
# Si_c: (-0.001030209009710056, 2.5942514989788676e-11)
# Si: -0.0008078958276615764
# continue
# end inside
# ---Start cycle inside---
# c: 0.07090010321814816
# g: [0.0709001 0.0709001 0.0709001 ... 0.0709001 0.0709001 0.0709001]
# idθ: [1195 2197 4022]
# θ[idθ]: [0.2391 0.4395 0.8045]
# Si_old_final: -0.0008078958276615764
# Si_c: (-0.000870451343638986, 2.5942514936133092e-11)
# Si: -0.0006952756975020257
# continue
# end inside
# ---Start cycle inside---
# c: 0.07070040613555932
# g: [0.07070041 0.07070041 0.07070041 ... 0.07070041 0.07070041 0.07070041]
# idθ: [1170 2248 4009]
# θ[idθ]: [0.2341 0.4497 0.8019]
# Si_old_final: -0.0006952756975020257
# Si_c: (-0.0007106936775679163, 2.5942514918247915e-11)
# Si: -0.0005821300068375742
# continue
# end inside
# ---Start cycle inside---
# c: 0.07050070905297048
# g: [0.07050071 0.07050071 0.07050071 ... 0.07050071 0.07050071 0.07050071]
# idθ: [1148 2297 3995]
# θ[idθ]: [0.2297 0.4595 0.7991]
# Si_old_final: -0.0005821300068375742
# Si_c: (-0.0005509360114968465, 2.5942514954018275e-11)
# Si: -0.00046856286882462775
# continue
# end inside
# ---Start cycle inside---
# c: 0.07030101197038165
# g: [0.07030101 0.07030101 0.07030101 ... 0.07030101 0.07030101 0.07030101]
# idθ: [1126 2346 3981]
# θ[idθ]: [0.2253 0.4693 0.7963]
# Si_old_final: -0.00046856286882462775
# Si_c: (-0.00039117834542577674, 2.5942514868410606e-11)
# Si: -0.0003546713029507597
# continue
# end inside
# ---Start cycle inside---
# c: 0.07010131488779281
# g: [0.07010131 0.07010131 0.07010131 ... 0.07010131 0.07010131 0.07010131]
# idθ: [1107 2393 3967]
# θ[idθ]: [0.2215 0.4787 0.7935]
# Si_old_final: -0.0003546713029507597
# Si_c: (-0.00023142067935470693, 2.5942514816664184e-11)
# Si: -0.00024053633503540146
# continue
# end inside
# ---Start cycle inside---
# c: 0.06990161780520397
# g: [0.06990162 0.06990162 0.06990162 ... 0.06990162 0.06990162 0.06990162]
# idθ: [1088 2441 3951]
# θ[idθ]: [0.2177 0.4883 0.7903]
# Si_old_final: -0.00024053633503540146
# Si_c: (-7.166301328363712e-05, 2.5942514988261355e-11)
# Si: -0.00012623597100761054
# continue
# end inside
# ---Start cycle inside---
# c: 0.06970192072261513
# g: [0.06970192 0.06970192 0.06970192 ... 0.06970192 0.06970192 0.06970192]
# idθ: [1071 2488 3935]
# θ[idθ]: [0.2143 0.4977 0.7871]
# Si_old_final: -0.00012623597100761054
# Si_c: (8.809465278743266e-05, 2.5942515022122588e-11)
# Si: -1.1846349480042272e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.0695022236400263
# g: [0.06950222 0.06950222 0.06950222 ... 0.06950222 0.06950222 0.06950222]
# idθ: [1054 2536 3918]
# θ[idθ]: [0.2109 0.5073 0.7837]
# Si_old_final: -1.1846349480042272e-05
# Si_c: (0.00024785231885850244, 2.5942514919202472e-11)
# Si: 0.0001025595017092246
# search aP
# aP: 0.0695022236400263
# aP2_fin: 0.06970192072261513
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.1846349480042272e-05
# -----!Si: 0.0001025595017092246
# -----!aP_fin: 0.06970192072261513
# ----------------------------------------
# End
# -----------New--------------
# ********* T =133.0 ********
# max_x: 0.31563653078974413
# min_x: 0.6843634508780242
# f_max_x: 0.07120755851362699
# f_min_x: 0.06546335586627706
# f_h_maxi: -0.00019969318411340177
# [0.07120756 0.07100787 0.07080817 0.07060848 0.07040879 0.07020909
#  0.0700094  0.06980971 0.06961001 0.06941032 0.06921063 0.06901093
#  0.06881124 0.06861155 0.06841185 0.06821216 0.06801247 0.06781277
#  0.06761308 0.06741339 0.06721369 0.067014   0.06681431 0.06661462
#  0.06641492 0.06621523 0.06601554 0.06581584 0.06561615]
# Lenth: 29
# ---Start cycle inside---
# c: 0.07120755851362699
# g: [0.07120756 0.07120756 0.07120756 ... 0.07120756 0.07120756 0.07120756]
# idθ: [1576 1578 4147]
# θ[idθ]: [0.3153 0.3157 0.8295]
# Si_old_final: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-7aa61ba64dd0> in <module>
#      75         print('Si_old_final: '+ str(Si_old_final))
#      76
# ---> 77         Si_c = ig.quad(f_c, a=0.1, b=0.9)
#      78         print('Si_c: ' + str(Si_c))
#      79
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\integrate\quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     349
#     350     if weight is None:
# --> 351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                        points)
#     353     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\integrate\quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-5-7aa61ba64dd0> in <lambda>(θ)
#      58
#      59         f = θ*(1+2*θ*(np.exp(-(R*T)**(-1)*ε)-1)/(1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ)+((1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ))**2+4*(np.exp(-(R*T)**(-1)*ε)-1)*θ**2)**0.5))**z_1/(1-θ)
# ---> 60         f_c = lambda θ:  -c+θ*(1+2*θ*(sp.exp(-(R*T)**(-1)*ε)-1)/(1+(sp.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ)+((1+(sp.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ))**2+4*(sp.exp(-(R*T)**(-1)*ε)-1)*θ**2)**0.5))**z_1/(1-θ)
#      61
#      62         print('---Start cycle inside---')
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\expr.py in __pow__(self, other, mod)
#     237     def __pow__(self, other, mod=None):
#     238         if mod is None:
# --> 239             return self._pow(other)
#     240         try:
#     241             _self, other, mod = as_int(self), as_int(other), as_int(mod)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\decorators.py in _func(self, other)
#     264             if not isinstance(other, expectedcls):
#     265                 return retval
# --> 266             return func(self, other)
#     267
#     268         return _func
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     134                     if f is not None:
#     135                         return f(self)
# --> 136             return func(self, other)
#     137         return binary_op_wrapper
#     138     return priority_decorator
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\expr.py in _pow(self, other)
#     233     @call_highest_priority('__rpow__')
#     234     def _pow(self, other):
# --> 235         return Pow(self, other)
#     236
#     237     def __pow__(self, other, mod=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\power.py in __new__(cls, b, e, evaluate)
#     309             # Only perform autosimplification if exponent or base is a Symbol or number
#     310             elif (b.is_Symbol or b.is_number) and (e.is_Symbol or e.is_number) and\
# --> 311                 e.is_integer and _coeff_isneg(b):
#     312                 if e.is_even:
#     313                     b = -b
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\function.py in _coeff_isneg(a)
#      91     if a.is_Mul:
#      92         a = a.args[0]
# ---> 93     return a.is_Number and a.is_extended_negative
#      94
#      95
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     501         a = evaluate(obj)
#     502         if a is not None:
# --> 503             assumptions.deduce_all_facts(((fact, a),))
#     504             return a
#     505
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\facts.py in deduce_all_facts(self, facts)
#     531             for bidx in beta_maytrigger:
#     532                 bcond, bimpl = beta_rules[bidx]
# --> 533                 if all(self.get(k) is v for k, v in bcond):
#     534                     facts.append(bimpl)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\facts.py in <genexpr>(.0)
#     531             for bidx in beta_maytrigger:
#     532                 bcond, bimpl = beta_rules[bidx]
# --> 533                 if all(self.get(k) is v for k, v in bcond):
#     534                     facts.append(bimpl)
#
# KeyboardInterrupt:

# %%
phase_diagram = []
T=146.6
phase_diagram.append([0.5, f1(0.5)]) #заношу в базу первую точку фазы
print(phase_diagram)

#T_start = T_krit2 - 1
T_start = 145
T_range = np.arange(T_start, 60.1, -1)

θ = np.arange(0.0001, 0.9999, 0.0002)

aP_fin = 0

#c = 0
#g = c+θ-θ

flag = False

for Ti in T_range: 
    print('-----------New--------------')
    T = Ti
    print('********* T ='+str(Ti)+' ********')
    
    max_x = opt.fminbound(f1_minus, 0, 0.5)
    min_x = opt.fminbound(f1, 0.5, 1)
    
    print('max_x: '+str(max_x) )
    print('min_x: '+str(min_x))
    
    h_maxi = 0.0002 #задаю шаг
    max_x = max_x + h_maxi
    min_x = min_x - h_maxi
    
    f_h_maxi = -f1(h_maxi)
    f_max_x = f1(max_x)
    f_min_x = f1 (min_x)
    
    print('f_max_x: '+str(f_max_x) )
    print('f_min_x: '+str(f_min_x))
    print('f_h_maxi: '+str(f_h_maxi))
    

    rng_line = np.arange(f_max_x, f_min_x, f_h_maxi) #диапазон max и min по оси Y 
    print(rng_line)
    print('Lenth: ' + str(len(rng_line)))
    
    span = np.arange(max_x, min_x, 0.0002) #диапазон max и min по оси X
    
    Si_old = 0
    Si_old_final = 0 
    Si_sum = 0
    aP = 0
    aP1_fin = 0
    aP2_fin = 0
    
    #Пробегаюсь по участкую от max до min
    for const in rng_line:
        
        f = θ*(1+2*θ*(np.exp(-(R*T)**(-1)*ε)-1)/(1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ)+((1+(np.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ))**2+4*(np.exp(-(R*T)**(-1)*ε)-1)*θ**2)**0.5))**z_1/(1-θ)
        f_c = lambda θ:  -c+θ*(1+2*θ*(sp.exp(-(R*T)**(-1)*ε)-1)/(1+(sp.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ)+((1+(sp.exp(-(R*T)**(-1)*ε)-1)*(1-2*θ))**2+4*(sp.exp(-(R*T)**(-1)*ε)-1)*θ**2)**0.5))**z_1/(1-θ)

        print('---Start cycle inside---')
        c = const
        g = c+θ-θ
        print('c: ' + str(c))
        
        print('g: '+str(g))
        idθ = np.argwhere(np.diff(np.sign(f - g))).flatten()
        
        print('idθ: '+str(idθ))
        print('θ[idθ]: '+str(θ[idθ]))

        Si_old_final = Si_old
        
        print('Si_old_final: '+ str(Si_old_final))
        
        Si_c = ig.quad(f_c, a=0.1, b=0.9)
        print('Si_c: ' + str(Si_c))
                
        
        Si = ig.quad(f_c, a=θ[idθ[0]], b=θ[idθ[2]])
        Si_old = Si[0]

        print('Si: ' + str(Si[0]))
        
        if Si[0] < 0:
            print('continue')
        else:
            print('search aP')
            aP = c
            print('aP: ' + str(aP))
            if abs(Si[0])<abs(Si_old_final):
                aP1_fin = c
                aP_fin = aP1_fin
                print('aP1_fin: ' + str(aP1_fin))
                flag == True
                print('Flag1 == True')
                print('break')
                break
            else:
                aP2_fin = c - f_h_maxi
                aP_fin = aP2_fin
                print('aP2_fin: ' + str(aP2_fin))
                flag == True
                print('Flag2 == True')
                print('break')
                break
        print('end inside')
    print('----------------------------------------')
    print('-----!Si_old_final: '+ str(Si_old_final))
    print('-----!Si: ' + str(Si[0]))
    print('-----!aP_fin: ' + str(aP_fin))
    print('----------------------------------------')
    #далее ищу точки пересечения найденной прямой с графиком
    
    for i in 0, 2:
        phase_diagram.append([θ[idθ[i]], T])
    print('End')
plt.scatter(*zip(*phase_diagram))
# Out:
# [[0.5, 0.08758042042172726]]
# -----------New--------------
# ********* T =145.0 ********
# max_x: 0.4341479578676005
# min_x: 0.5658548824728018
# f_max_x: 0.08540498407170649
# f_min_x: 0.0851120110169682
# f_h_maxi: -0.00019973500024608759
# [0.08540498 0.08520525]
# Lenth: 2
# ---Start cycle inside---
# c: 0.08540498407170649
# g: [0.08540498 0.08540498 0.08540498 ... 0.08540498 0.08540498 0.08540498]
# idθ: [2169 2171 3148]
# θ[idθ]: [0.4339 0.4343 0.6297]
# Si_old_final: 0
# Si_c: (0.00036305995115746593, 3.3181534434665875e-11)
# Si: -3.2252391154928626e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.0852052490714604
# g: [0.08520525 0.08520525 0.08520525 ... 0.08520525 0.08520525 0.08520525]
# idθ: [1899 2581 3020]
# θ[idθ]: [0.3799 0.5163 0.6041]
# Si_old_final: -3.2252391154928626e-05
# Si_c: (0.0005228479513543355, 3.318153415991941e-11)
# Si: 1.1984608387695756e-05
# search aP
# aP: 0.0852052490714604
# aP1_fin: 0.0852052490714604
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -3.2252391154928626e-05
# -----!Si: 1.1984608387695756e-05
# -----!aP_fin: 0.0852052490714604
# ----------------------------------------
# End
# -----------New--------------
# ********* T =144.0 ********
# max_x: 0.4174221060722178
# min_x: 0.5825777651530841
# f_max_x: 0.08409997548749093
# f_min_x: 0.08352708488668927
# f_h_maxi: -0.0001997318901436526
# [0.08409998 0.08390024 0.08370051]
# Lenth: 3
# ---Start cycle inside---
# c: 0.08409997548749093
# g: [0.08409998 0.08409998 0.08409998 ... 0.08409998 0.08409998 0.08409998]
# idθ: [2085 2087 3306]
# θ[idθ]: [0.4171 0.4175 0.6613]
# Si_old_final: 0
# Si_c: (0.0002022464869349868, 3.241988960916421e-11)
# Si: -7.867431165577406e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08390024359734728
# g: [0.08390024 0.08390024 0.08390024 ... 0.08390024 0.08390024 0.08390024]
# idθ: [1838 2413 3239]
# θ[idθ]: [0.3677 0.4827 0.6479]
# Si_old_final: -7.867431165577406e-05
# Si_c: (0.0003620319990499054, 3.2419888587072204e-11)
# Si: -2.4449435674679323e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08370051170720363
# g: [0.08370051 0.08370051 0.08370051 ... 0.08370051 0.08370051 0.08370051]
# idθ: [1749 2611 3145]
# θ[idθ]: [0.3499 0.5223 0.6291]
# Si_old_final: -2.4449435674679323e-05
# Si_c: (0.0005218175111648237, 3.2419888788562764e-11)
# Si: 3.16744501836144e-05
# search aP
# aP: 0.08370051170720363
# aP2_fin: 0.08390024359734728
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -2.4449435674679323e-05
# -----!Si: 3.16744501836144e-05
# -----!aP_fin: 0.08390024359734728
# ----------------------------------------
# End
# -----------New--------------
# ********* T =143.0 ********
# max_x: 0.4035652760287722
# min_x: 0.5964346177200278
# f_max_x: 0.08282608021439085
# f_min_x: 0.08192142652428566
# f_h_maxi: -0.00019972871846714205
# [0.08282608 0.08262635 0.08242662 0.08222689 0.08202717]
# Lenth: 5
# ---Start cycle inside---
# c: 0.08282608021439085
# g: [0.08282608 0.08282608 0.08282608 ... 0.08282608 0.08282608 0.08282608]
# idθ: [2016 2018 3434]
# θ[idθ]: [0.4033 0.4037 0.6869]
# Si_old_final: 0
# Si_c: (2.3740569488392167e-05, 3.16824312261688e-11)
# Si: -0.0001443435851658922
# continue
# end inside
# ---Start cycle inside---
# c: 0.0826263514959237
# g: [0.08262635 0.08262635 0.08262635 ... 0.08262635 0.08262635 0.08262635]
# idθ: [1785 2307 3388]
# θ[idθ]: [0.3571 0.4615 0.6777]
# Si_old_final: -0.0001443435851658922
# Si_c: (0.00018352354426210684, 3.16824306374201e-11)
# Si: -8.230839579884934e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08242662277745656
# g: [0.08242662 0.08242662 0.08242662 ... 0.08242662 0.08242662 0.08242662]
# idθ: [1700 2460 3334]
# θ[idθ]: [0.3401 0.4921 0.6669]
# Si_old_final: -8.230839579884934e-05
# Si_c: (0.00034330651903582087, 3.168243033915059e-11)
# Si: -1.748661093049822e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08222689405898942
# g: [0.08222689 0.08222689 0.08222689 ... 0.08222689 0.08222689 0.08222689]
# idθ: [1638 2605 3264]
# θ[idθ]: [0.3277 0.5211 0.6529]
# Si_old_final: -1.748661093049822e-05
# Si_c: (0.0005030894938095351, 3.168243016050595e-11)
# Si: 4.774813431125603e-05
# search aP
# aP: 0.08222689405898942
# aP2_fin: 0.08242662277745656
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.748661093049822e-05
# -----!Si: 4.774813431125603e-05
# -----!aP_fin: 0.08242662277745656
# ----------------------------------------
# End
# -----------New--------------
# ********* T =142.0 ********
# max_x: 0.3914713536643228
# min_x: 0.608528691284826
# f_max_x: 0.08157863726088499
# f_min_x: 0.08030036082778032
# f_h_maxi: -0.0001997254834242651
# [0.08157864 0.08137891 0.08117919 0.08097946 0.08077974 0.08058001
#  0.08038028]
# Lenth: 7
# ---Start cycle inside---
# c: 0.08157863726088499
# g: [0.08157864 0.08157864 0.08157864 ... 0.08157864 0.08157864 0.08157864]
# idθ: [1955 1957 3542]
# θ[idθ]: [0.3911 0.3915 0.7085]
# Si_old_final: 0
# Si_c: (-0.0001686105040414321, 3.096999595885783e-11)
# Si: -0.0002283865434331342
# continue
# end inside
# ---Start cycle inside---
# c: 0.08137891177746072
# g: [0.08137891 0.08137891 0.08137891 ... 0.08137891 0.08137891 0.08137891]
# idθ: [1736 2224 3508]
# θ[idθ]: [0.3473 0.4449 0.7017]
# Si_old_final: -0.0002283865434331342
# Si_c: (-8.830117302015576e-06, 3.096999561046069e-11)
# Si: -0.00015972220921716594
# continue
# end inside
# ---Start cycle inside---
# c: 0.08117918629403645
# g: [0.08117919 0.08117919 0.08117919 ... 0.08117919 0.08117919 0.08117919]
# idθ: [1654 2357 3469]
# θ[idθ]: [0.3309 0.4715 0.6939]
# Si_old_final: -0.00015972220921716594
# Si_c: (0.00015095026943740117, 3.096999522624532e-11)
# Si: -8.795031453969973e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08097946081061218
# g: [0.08097946 0.08097946 0.08097946 ... 0.08097946 0.08097946 0.08097946]
# idθ: [1595 2475 3425]
# θ[idθ]: [0.3191 0.4951 0.6851]
# Si_old_final: -8.795031453969973e-05
# Si_c: (0.00031073065617681704, 3.0969995075241855e-11)
# Si: -1.5076537685446918e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.08077973532718791
# g: [0.08077974 0.08077974 0.08077974 ... 0.08077974 0.08077974 0.08077974]
# idθ: [1547 2590 3371]
# θ[idθ]: [0.3095 0.5181 0.6743]
# Si_old_final: -1.5076537685446918e-05
# Si_c: (0.00047051104291623356, 3.096999500715241e-11)
# Si: 5.797102380856996e-05
# search aP
# aP: 0.08077973532718791
# aP2_fin: 0.08097946081061218
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.5076537685446918e-05
# -----!Si: 5.797102380856996e-05
# -----!aP_fin: 0.08097946081061218
# ----------------------------------------
# End
# -----------New--------------
# ********* T =141.0 ********
# max_x: 0.38060557314577803
# min_x: 0.6193944026090353
# f_max_x: 0.08035454974278661
# f_min_x: 0.07866765313312686
# f_h_maxi: -0.00019972218315413205
# [0.08035455 0.08015483 0.07995511 0.07975538 0.07955566 0.07935594
#  0.07915622 0.07895649 0.07875677]
# Lenth: 9
# ---Start cycle inside---
# c: 0.08035454974278661
# g: [0.08035455 0.08035455 0.08035455 ... 0.08035455 0.08035455 0.08035455]
# idθ: [1901 1903 3637]
# θ[idθ]: [0.3803 0.3807 0.7275]
# Si_old_final: 0
# Si_c: (-0.00037221021107052, 3.028356339142231e-11)
# Si: -0.0003299416693260009
# continue
# end inside
# ---Start cycle inside---
# c: 0.08015482755963248
# g: [0.08015483 0.08015483 0.08015483 ... 0.08015483 0.08015483 0.08015483]
# idθ: [1691 2153 3610]
# θ[idθ]: [0.3383 0.4307 0.7221]
# Si_old_final: -0.0003299416693260009
# Si_c: (-0.00021243246454721604, 3.028356277936303e-11)
# Si: -0.0002554427368140815
# continue
# end inside
# ---Start cycle inside---
# c: 0.07995510537647835
# g: [0.07995511 0.07995511 0.07995511 ... 0.07995511 0.07995511 0.07995511]
# idθ: [1612 2275 3580]
# θ[idθ]: [0.3225 0.4551 0.7161]
# Si_old_final: -0.0002554427368140815
# Si_c: (-5.265471802391188e-05, 3.028356239242513e-11)
# Si: -0.00017769780733188707
# continue
# end inside
# ---Start cycle inside---
# c: 0.07975538319332422
# g: [0.07975538 0.07975538 0.07975538 ... 0.07975538 0.07975538 0.07975538]
# idθ: [1555 2378 3547]
# θ[idθ]: [0.3111 0.4757 0.7095]
# Si_old_final: -0.00017769780733188707
# Si_c: (0.00010712302849939207, 3.0283562177411616e-11)
# Si: -9.853859898189875e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07955566101017009
# g: [0.07955566 0.07955566 0.07955566 ... 0.07955566 0.07955566 0.07955566]
# idθ: [1508 2475 3510]
# θ[idθ]: [0.3017 0.4951 0.7021]
# Si_old_final: -9.853859898189875e-05
# Si_c: (0.00026690077502269645, 3.028356229290967e-11)
# Si: -1.8714801606451994e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07935593882701596
# g: [0.07935594 0.07935594 0.07935594 ... 0.07935594 0.07935594 0.07935594]
# idθ: [1468 2572 3467]
# θ[idθ]: [0.2937 0.5145 0.6935]
# Si_old_final: -1.8714801606451994e-05
# Si_c: (0.0004266785215460004, 3.028356208295233e-11)
# Si: 6.123283303430049e-05
# search aP
# aP: 0.07935593882701596
# aP2_fin: 0.07955566101017009
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.8714801606451994e-05
# -----!Si: 6.123283303430049e-05
# -----!aP_fin: 0.07955566101017009
# ----------------------------------------
# End
# -----------New--------------
# ********* T =140.0 ********
# max_x: 0.3706570987137918
# min_x: 0.6293428582524709
# f_max_x: 0.07915155746732655
# f_min_x: 0.07702623625783676
# f_h_maxi: -0.00019971881572400322
# [0.07915156 0.07895184 0.07875212 0.0785524  0.07835268 0.07815296
#  0.07795324 0.07775353 0.07755381 0.07735409 0.07715437]
# Lenth: 11
# ---Start cycle inside---
# c: 0.07915155746732655
# g: [0.07915156 0.07915156 0.07915156 ... 0.07915156 0.07915156 0.07915156]
# idθ: [1851 1853 3722]
# θ[idθ]: [0.3703 0.3707 0.7445]
# Si_old_final: 0
# Si_c: (-0.0005851309018399711, 2.9624315147223563e-11)
# Si: -0.00044815767866361025
# continue
# end inside
# ---Start cycle inside---
# c: 0.07895183865160255
# g: [0.07895184 0.07895184 0.07895184 ... 0.07895184 0.07895184 0.07895184]
# idθ: [1649 2091 3700]
# θ[idθ]: [0.3299 0.4183 0.7401]
# Si_old_final: -0.00044815767866361025
# Si_c: (-0.0004253558492607677, 2.962431438036251e-11)
# Si: -0.0003684134084596468
# continue
# end inside
# ---Start cycle inside---
# c: 0.07875211983587854
# g: [0.07875212 0.07875212 0.07875212 ... 0.07875212 0.07875212 0.07875212]
# idθ: [1573 2204 3676]
# θ[idθ]: [0.3147 0.4409 0.7353]
# Si_old_final: -0.0003684134084596468
# Si_c: (-0.0002655807966815643, 2.962431412668076e-11)
# Si: -0.00028536403948761085
# continue
# end inside
# ---Start cycle inside---
# c: 0.07855240102015454
# g: [0.0785524 0.0785524 0.0785524 ... 0.0785524 0.0785524 0.0785524]
# idθ: [1517 2299 3650]
# θ[idθ]: [0.3035 0.4599 0.7301]
# Si_old_final: -0.00028536403948761085
# Si_c: (-0.0001058057441023618, 2.962431384089591e-11)
# Si: -0.00020073183139098202
# continue
# end inside
# ---Start cycle inside---
# c: 0.07835268220443053
# g: [0.07835268 0.07835268 0.07835268 ... 0.07835268 0.07835268 0.07835268]
# idθ: [1472 2386 3621]
# θ[idθ]: [0.2945 0.4773 0.7243]
# Si_old_final: -0.00020073183139098202
# Si_c: (5.396930847684114e-05, 2.962431384395404e-11)
# Si: -0.0001151822633023701
# continue
# end inside
# ---Start cycle inside---
# c: 0.07815296338870653
# g: [0.07815296 0.07815296 0.07815296 ... 0.07815296 0.07815296 0.07815296]
# idθ: [1433 2469 3590]
# θ[idθ]: [0.2867 0.4939 0.7181]
# Si_old_final: -0.0001151822633023701
# Si_c: (0.0002137443610560441, 2.962431372154382e-11)
# Si: -2.9155013022631216e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07795324457298253
# g: [0.07795324 0.07795324 0.07795324 ... 0.07795324 0.07795324 0.07795324]
# idθ: [1399 2552 3554]
# θ[idθ]: [0.2799 0.5105 0.7109]
# Si_old_final: -2.9155013022631216e-05
# Si_c: (0.00037351941363524726, 2.9624313658990145e-11)
# Si: 5.6994045079043014e-05
# search aP
# aP: 0.07795324457298253
# aP2_fin: 0.07815296338870653
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -2.9155013022631216e-05
# -----!Si: 5.6994045079043014e-05
# -----!aP_fin: 0.07815296338870653
# ----------------------------------------
# End
# -----------New--------------
# ********* T =139.0 ********
# max_x: 0.36142814828225295
# min_x: 0.6385719278939289
# f_max_x: 0.07796791253510539
# f_min_x: 0.0753785344991957
# f_h_maxi: -0.00019971537912585565
# [0.07796791 0.0777682  0.07756848 0.07736877 0.07716905 0.07696934
#  0.07676962 0.0765699  0.07637019 0.07617047 0.07597076 0.07577104
#  0.07557133]
# Lenth: 13
# ---Start cycle inside---
# c: 0.07796791253510539
# g: [0.07796791 0.07796791 0.07796791 ... 0.07796791 0.07796791 0.07796791]
# idθ: [1805 1807 3799]
# θ[idθ]: [0.3611 0.3615 0.7599]
# Si_old_final: 0
# Si_c: (-0.0008058543133630186, 2.897809699095717e-11)
# Si: -0.0005821929621884178
# continue
# end inside
# ---Start cycle inside---
# c: 0.07776819715597953
# g: [0.0777682 0.0777682 0.0777682 ... 0.0777682 0.0777682 0.0777682]
# idθ: [1610 2034 3780]
# θ[idθ]: [0.3221 0.4069 0.7561]
# Si_old_final: -0.0005821929621884178
# Si_c: (-0.0006460820100623318, 2.8978096295355345e-11)
# Si: -0.0004976652445615742
# continue
# end inside
# ---Start cycle inside---
# c: 0.07756848177685367
# g: [0.07756848 0.07756848 0.07756848 ... 0.07756848 0.07756848 0.07756848]
# idθ: [1536 2141 3760]
# θ[idθ]: [0.3073 0.4283 0.7521]
# Si_old_final: -0.0004976652445615742
# Si_c: (-0.00048630970676164485, 2.897809634858499e-11)
# Si: -0.00040981397337506135
# continue
# end inside
# ---Start cycle inside---
# c: 0.07736876639772781
# g: [0.07736877 0.07736877 0.07736877 ... 0.07736877 0.07736877 0.07736877]
# idθ: [1482 2230 3738]
# θ[idθ]: [0.2965 0.4461 0.7477]
# Si_old_final: -0.00040981397337506135
# Si_c: (-0.000326537403460958, 2.8978096348584992e-11)
# Si: -0.0003202800098686957
# continue
# end inside
# ---Start cycle inside---
# c: 0.07716905101860196
# g: [0.07716905 0.07716905 0.07716905 ... 0.07716905 0.07716905 0.07716905]
# idθ: [1437 2311 3715]
# θ[idθ]: [0.2875 0.4623 0.7431]
# Si_old_final: -0.0003202800098686957
# Si_c: (-0.00016676510016027063, 2.8978096346371208e-11)
# Si: -0.00022968207060732098
# continue
# end inside
# ---Start cycle inside---
# c: 0.0769693356394761
# g: [0.07696934 0.07696934 0.07696934 ... 0.07696934 0.07696934 0.07696934]
# idθ: [1400 2386 3691]
# θ[idθ]: [0.2801 0.4773 0.7383]
# Si_old_final: -0.00022968207060732098
# Si_c: (-6.992796859583679e-06, 2.897809634858499e-11)
# Si: -0.0001384063425071676
# continue
# end inside
# ---Start cycle inside---
# c: 0.07676962026035024
# g: [0.07676962 0.07676962 0.07676962 ... 0.07676962 0.07676962 0.07676962]
# idθ: [1366 2460 3664]
# θ[idθ]: [0.2733 0.4921 0.7329]
# Si_old_final: -0.0001384063425071676
# Si_c: (0.00015277950644110349, 2.897809634858499e-11)
# Si: -4.674706779908223e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07656990488122438
# g: [0.0765699 0.0765699 0.0765699 ... 0.0765699 0.0765699 0.0765699]
# idθ: [1336 2533 3634]
# θ[idθ]: [0.2673 0.5067 0.7269]
# Si_old_final: -4.674706779908223e-05
# Si_c: (0.00031255180974179043, 2.8978096221164352e-11)
# Si: 4.504266712760498e-05
# search aP
# aP: 0.07656990488122438
# aP1_fin: 0.07656990488122438
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -4.674706779908223e-05
# -----!Si: 4.504266712760498e-05
# -----!aP_fin: 0.07656990488122438
# ----------------------------------------
# End
# -----------New--------------
# ********* T =138.0 ********
# max_x: 0.3527849481720895
# min_x: 0.6472152581106354
# f_max_x: 0.0768022088563015
# f_min_x: 0.0737266336730937
# f_h_maxi: -0.00019971187127275318
# [0.07680221 0.0766025  0.07640279 0.07620307 0.07600336 0.07580365
#  0.07560394 0.07540423 0.07520451 0.0750048  0.07480509 0.07460538
#  0.07440567 0.07420595 0.07400624 0.07380653]
# Lenth: 16
# ---Start cycle inside---
# c: 0.0768022088563015
# g: [0.07680221 0.07680221 0.07680221 ... 0.07680221 0.07680221 0.07680221]
# idθ: [1762 1764 3869]
# θ[idθ]: [0.3525 0.3529 0.7739]
# Si_old_final: 0
# Si_c: (-0.0010331352161889267, 2.8311991102738843e-11)
# Si: -0.0007312155175746175
# continue
# end inside
# ---Start cycle inside---
# c: 0.07660249698502875
# g: [0.0766025 0.0766025 0.0766025 ... 0.0766025 0.0766025 0.0766025]
# idθ: [1573 1983 3852]
# θ[idθ]: [0.3147 0.3967 0.7705]
# Si_old_final: -0.0007312155175746175
# Si_c: (-0.0008733657191707239, 2.8311990911782476e-11)
# Si: -0.0006422806618642587
# continue
# end inside
# ---Start cycle inside---
# c: 0.07640278511375599
# g: [0.07640279 0.07640279 0.07640279 ... 0.07640279 0.07640279 0.07640279]
# idθ: [1501 2085 3835]
# θ[idθ]: [0.3003 0.4171 0.7671]
# Si_old_final: -0.0006422806618642587
# Si_c: (-0.000713596222152521, 2.8311991167963233e-11)
# Si: -0.0005500265983757389
# continue
# end inside
# ---Start cycle inside---
# c: 0.07620307324248324
# g: [0.07620307 0.07620307 0.07620307 ... 0.07620307 0.07620307 0.07620307]
# idθ: [1448 2169 3817]
# θ[idθ]: [0.2897 0.4339 0.7635]
# Si_old_final: -0.0005500265983757389
# Si_c: (-0.0005538267251343181, 2.8311991039872855e-11)
# Si: -0.0004560304511106817
# continue
# end inside
# ---Start cycle inside---
# c: 0.07600336137121048
# g: [0.07600336 0.07600336 0.07600336 ... 0.07600336 0.07600336 0.07600336]
# idθ: [1405 2244 3798]
# θ[idθ]: [0.2811 0.4489 0.7597]
# Si_old_final: -0.0004560304511106817
# Si_c: (-0.00039405722811611536, 2.831199104105209e-11)
# Si: -0.0003608755399567274
# continue
# end inside
# ---Start cycle inside---
# c: 0.07580364949993773
# g: [0.07580365 0.07580365 0.07580365 ... 0.07580365 0.07580365 0.07580365]
# idθ: [1368 2315 3778]
# θ[idθ]: [0.2737 0.4631 0.7557]
# Si_old_final: -0.0003608755399567274
# Si_c: (-0.00023428773109791248, 2.831199110509729e-11)
# Si: -0.0002649183653601546
# continue
# end inside
# ---Start cycle inside---
# c: 0.07560393762866498
# g: [0.07560394 0.07560394 0.07560394 ... 0.07560394 0.07560394 0.07560394]
# idθ: [1335 2382 3756]
# θ[idθ]: [0.2671 0.4765 0.7513]
# Si_old_final: -0.0002649183653601546
# Si_c: (-7.451823407970937e-05, 2.8311991103918053e-11)
# Si: -0.00016841883546434307
# continue
# end inside
# ---Start cycle inside---
# c: 0.07540422575739222
# g: [0.07540423 0.07540423 0.07540423 ... 0.07540423 0.07540423 0.07540423]
# idθ: [1306 2448 3733]
# θ[idθ]: [0.2613 0.4897 0.7467]
# Si_old_final: -0.00016841883546434307
# Si_c: (8.525126293849341e-05, 2.8311991103918053e-11)
# Si: -7.158988649612901e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07520451388611947
# g: [0.07520451 0.07520451 0.07520451 ... 0.07520451 0.07520451 0.07520451]
# idθ: [1279 2513 3707]
# θ[idθ]: [0.2559 0.5027 0.7415]
# Si_old_final: -7.158988649612901e-05
# Si_c: (0.0002450207599566963, 2.8311991488189176e-11)
# Si: 2.53797939155958e-05
# search aP
# aP: 0.07520451388611947
# aP1_fin: 0.07520451388611947
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -7.158988649612901e-05
# -----!Si: 2.53797939155958e-05
# -----!aP_fin: 0.07520451388611947
# ----------------------------------------
# End
# -----------New--------------
# ********* T =137.0 ********
# max_x: 0.3446290416289224
# min_x: 0.6553710117373452
# f_max_x: 0.07565328266732683
# f_min_x: 0.07207238013342743
# f_h_maxi: -0.00019970828999500833
# [0.07565328 0.07545357 0.07525387 0.07505416 0.07485445 0.07465474
#  0.07445503 0.07425532 0.07405562 0.07385591 0.0736562  0.07345649
#  0.07325678 0.07305707 0.07285737 0.07265766 0.07245795 0.07225824]
# Lenth: 18
# ---Start cycle inside---
# c: 0.07565328266732683
# g: [0.07565328 0.07565328 0.07565328 ... 0.07565328 0.07565328 0.07565328]
# idθ: [1721 1723 3933]
# θ[idθ]: [0.3443 0.3447 0.7867]
# Si_old_final: 0
# Si_c: (-0.00126592186296985, 2.7673747560571743e-11)
# Si: -0.0008944029798860941
# continue
# end inside
# ---Start cycle inside---
# c: 0.07545357437733183
# g: [0.07545357 0.07545357 0.07545357 ... 0.07545357 0.07545357 0.07545357]
# idθ: [1537 1934 3919]
# θ[idθ]: [0.3075 0.3869 0.7839]
# Si_old_final: -0.0008944029798860941
# Si_c: (-0.0011061552309738444, 2.7673747591819786e-11)
# Si: -0.0008013782155389733
# continue
# end inside
# ---Start cycle inside---
# c: 0.07525386608733682
# g: [0.07525387 0.07525387 0.07525387 ... 0.07525387 0.07525387 0.07525387]
# idθ: [1467 2033 3904]
# θ[idθ]: [0.2935 0.4067 0.7809]
# Si_old_final: -0.0008013782155389733
# Si_c: (-0.0009463885989778386, 2.767374752680898e-11)
# Si: -0.0007050495191322872
# continue
# end inside
# ---Start cycle inside---
# c: 0.07505415779734181
# g: [0.07505416 0.07505416 0.07505416 ... 0.07505416 0.07505416 0.07505416]
# idθ: [1415 2113 3888]
# θ[idθ]: [0.2831 0.4227 0.7777]
# Si_old_final: -0.0007050495191322872
# Si_c: (-0.0007866219669818331, 2.7673747591819786e-11)
# Si: -0.0006069420242107073
# continue
# end inside
# ---Start cycle inside---
# c: 0.0748544495073468
# g: [0.07485445 0.07485445 0.07485445 ... 0.07485445 0.07485445 0.07485445]
# idθ: [1373 2184 3872]
# θ[idθ]: [0.2747 0.4369 0.7745]
# Si_old_final: -0.0006069420242107073
# Si_c: (-0.0006268553349858272, 2.7673747655573265e-11)
# Si: -0.0005076150498259666
# continue
# end inside
# ---Start cycle inside---
# c: 0.0746547412173518
# g: [0.07465474 0.07465474 0.07465474 ... 0.07465474 0.07465474 0.07465474]
# idθ: [1337 2251 3855]
# θ[idθ]: [0.2675 0.4503 0.7711]
# Si_old_final: -0.0005076150498259666
# Si_c: (-0.0004670887029898219, 2.7673747460540843e-11)
# Si: -0.00040740235954352864
# continue
# end inside
# ---Start cycle inside---
# c: 0.07445503292735679
# g: [0.07445503 0.07445503 0.07445503 ... 0.07445503 0.07445503 0.07445503]
# idθ: [1305 2314 3837]
# θ[idθ]: [0.2611 0.4629 0.7675]
# Si_old_final: -0.00040740235954352864
# Si_c: (-0.00030732207099381614, 2.7673747656830596e-11)
# Si: -0.00030654370722017977
# continue
# end inside
# ---Start cycle inside---
# c: 0.07425532463736179
# g: [0.07425532 0.07425532 0.07425532 ... 0.07425532 0.07425532 0.07425532]
# idθ: [1277 2375 3818]
# θ[idθ]: [0.2555 0.4751 0.7637]
# Si_old_final: -0.00030654370722017977
# Si_c: (-0.0001475554389978105, 2.7673747655573265e-11)
# Si: -0.00020522767235456505
# continue
# end inside
# ---Start cycle inside---
# c: 0.07405561634736678
# g: [0.07405562 0.07405562 0.07405562 ... 0.07405562 0.07405562 0.07405562]
# idθ: [1251 2435 3797]
# θ[idθ]: [0.2503 0.4871 0.7595]
# Si_old_final: -0.00020522767235456505
# Si_c: (1.2211192998194936e-05, 2.7673747526180313e-11)
# Si: -0.00010361608679627562
# continue
# end inside
# ---Start cycle inside---
# c: 0.07385590805737177
# g: [0.07385591 0.07385591 0.07385591 ... 0.07385591 0.07385591 0.07385591]
# idθ: [1226 2495 3775]
# θ[idθ]: [0.2453 0.4991 0.7551]
# Si_old_final: -0.00010361608679627562
# Si_c: (0.0001719778249942007, 2.7673747654944608e-11)
# Si: -1.8560771106392563e-06
# continue
# end inside
# ---Start cycle inside---
# c: 0.07365619976737676
# g: [0.0736562 0.0736562 0.0736562 ... 0.0736562 0.0736562 0.0736562]
# idθ: [1204 2554 3751]
# θ[idθ]: [0.2409 0.5109 0.7503]
# Si_old_final: -1.8560771106392563e-06
# Si_c: (0.00033174445699020634, 2.7673747657459272e-11)
# Si: 9.991559533423309e-05
# search aP
# aP: 0.07365619976737676
# aP2_fin: 0.07385590805737177
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.8560771106392563e-06
# -----!Si: 9.991559533423309e-05
# -----!aP_fin: 0.07385590805737177
# ----------------------------------------
# End
# -----------New--------------
# ********* T =136.0 ********
# max_x: 0.3368847655492829
# min_x: 0.6631152662309869
# f_max_x: 0.07452014967309861
# f_min_x: 0.07041744309533149
# f_h_maxi: -0.00019970463303612215
# [0.07452015 0.07432045 0.07412074 0.07392104 0.07372133 0.07352163
#  0.07332192 0.07312222 0.07292251 0.07272281 0.0725231  0.0723234
#  0.07212369 0.07192399 0.07172428 0.07152458 0.07132488 0.07112517
#  0.07092547 0.07072576 0.07052606]
# Lenth: 21
# ---Start cycle inside---
# c: 0.07452014967309861
# g: [0.07452015 0.07452015 0.07452015 ... 0.07452015 0.07452015 0.07452015]
# idθ: [1682 1684 3992]
# θ[idθ]: [0.3365 0.3369 0.7985]
# Si_old_final: 0
# Si_c: (-0.001503305738994774, 2.706485155336986e-11)
# Si: -0.0010709416654421247
# continue
# end inside
# ---Start cycle inside---
# c: 0.0743204450400625
# g: [0.07432045 0.07432045 0.07432045 ... 0.07432045 0.07432045 0.07432045]
# idθ: [1503 1889 3980]
# θ[idθ]: [0.3007 0.3779 0.7961]
# Si_old_final: -0.0010709416654421247
# Si_c: (-0.001343542032565879, 2.706485153685382e-11)
# Si: -0.0009740964927364563
# continue
# end inside
# ---Start cycle inside---
# c: 0.07412074040702638
# g: [0.07412074 0.07412074 0.07412074 ... 0.07412074 0.07412074 0.07412074]
# idθ: [1434 1984 3967]
# θ[idθ]: [0.2869 0.3969 0.7935]
# Si_old_final: -0.0009740964927364563
# Si_c: (-0.0011837783261369843, 2.7064851622116025e-11)
# Si: -0.0008739716047827078
# continue
# end inside
# ---Start cycle inside---
# c: 0.07392103577399026
# g: [0.07392104 0.07392104 0.07392104 ... 0.07392104 0.07392104 0.07392104]
# idθ: [1384 2061 3953]
# θ[idθ]: [0.2769 0.4123 0.7907]
# Si_old_final: -0.0008739716047827078
# Si_c: (-0.0010240146197080893, 2.7064851571226898e-11)
# Si: -0.0007720461649805322
# continue
# end inside
# ---Start cycle inside---
# c: 0.07372133114095414
# g: [0.07372133 0.07372133 0.07372133 ... 0.07372133 0.07372133 0.07372133]
# idθ: [1343 2130 3939]
# θ[idθ]: [0.2687 0.4261 0.7879]
# Si_old_final: -0.0007720461649805322
# Si_c: (-0.0008642509132791945, 2.7064851488646717e-11)
# Si: -0.000668859780901536
# continue
# end inside
# ---Start cycle inside---
# c: 0.07352162650791802
# g: [0.07352163 0.07352163 0.07352163 ... 0.07352163 0.07352163 0.07352163]
# idθ: [1308 2193 3924]
# θ[idθ]: [0.2617 0.4387 0.7849]
# Si_old_final: -0.000668859780901536
# Si_c: (-0.0007044872068502996, 2.706485165246606e-11)
# Si: -0.0005647300694300862
# continue
# end inside
# ---Start cycle inside---
# c: 0.0733219218748819
# g: [0.07332192 0.07332192 0.07332192 ... 0.07332192 0.07332192 0.07332192]
# idθ: [1276 2253 3909]
# θ[idθ]: [0.2553 0.4507 0.7819]
# Si_old_final: -0.0005647300694300862
# Si_c: (-0.000544723500421405, 2.7064851487305715e-11)
# Si: -0.00045988450905610345
# continue
# end inside
# ---Start cycle inside---
# c: 0.07312221724184578
# g: [0.07312222 0.07312222 0.07312222 ... 0.07312222 0.07312222 0.07312222]
# idθ: [1248 2310 3893]
# θ[idθ]: [0.2497 0.4621 0.7787]
# Si_old_final: -0.00045988450905610345
# Si_c: (-0.0003849597939925103, 2.7064851389550515e-11)
# Si: -0.0003544939859059706
# continue
# end inside
# ---Start cycle inside---
# c: 0.07292251260880966
# g: [0.07292251 0.07292251 0.07292251 ... 0.07292251 0.07292251 0.07292251]
# idθ: [1223 2366 3875]
# θ[idθ]: [0.2447 0.4733 0.7751]
# Si_old_final: -0.0003544939859059706
# Si_c: (-0.00022519608756361537, 2.7064851456285156e-11)
# Si: -0.00024870253038670597
# continue
# end inside
# ---Start cycle inside---
# c: 0.07272280797577355
# g: [0.07272281 0.07272281 0.07272281 ... 0.07272281 0.07272281 0.07272281]
# idθ: [1199 2421 3857]
# θ[idθ]: [0.2399 0.4843 0.7715]
# Si_old_final: -0.00024870253038670597
# Si_c: (-6.54323811347206e-05, 2.7064851523019817e-11)
# Si: -0.00014264094207370876
# continue
# end inside
# ---Start cycle inside---
# c: 0.07252310334273743
# g: [0.0725231 0.0725231 0.0725231 ... 0.0725231 0.0725231 0.0725231]
# idθ: [1177 2476 3838]
# θ[idθ]: [0.2355 0.4953 0.7677]
# Si_old_final: -0.00014264094207370876
# Si_c: (9.433132529417421e-05, 2.7064851456285156e-11)
# Si: -3.642256314426512e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07232339870970131
# g: [0.0723234 0.0723234 0.0723234 ... 0.0723234 0.0723234 0.0723234]
# idθ: [1157 2531 3817]
# θ[idθ]: [0.2315 0.5063 0.7635]
# Si_old_final: -3.642256314426512e-05
# Si_c: (0.000254095031723069, 2.7064851653807062e-11)
# Si: 6.984292050033934e-05
# search aP
# aP: 0.07232339870970131
# aP2_fin: 0.07252310334273743
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -3.642256314426512e-05
# -----!Si: 6.984292050033934e-05
# -----!aP_fin: 0.07252310334273743
# ----------------------------------------
# End
# -----------New--------------
# ********* T =135.0 ********
# max_x: 0.3295005458477885
# min_x: 0.6704994686446191
# f_max_x: 0.07340196261806248
# f_min_x: 0.0687633565752531
# f_h_maxi: -0.0001997008980484863
# [0.07340196 0.07320226 0.07300256 0.07280286 0.07260316 0.07240346
#  0.07220376 0.07200406 0.07180436 0.07160465 0.07140495 0.07120525
#  0.07100555 0.07080585 0.07060615 0.07040645 0.07020675 0.07000705
#  0.06980735 0.06960765 0.06940794 0.06920824 0.06900854 0.06880884]
# Lenth: 24
# ---Start cycle inside---
# c: 0.07340196261806248
# g: [0.07340196 0.07340196 0.07340196 ... 0.07340196 0.07340196 0.07340196]
# idθ: [1646 1648 4047]
# θ[idθ]: [0.3293 0.3297 0.8095]
# Si_old_final: 0
# Si_c: (-0.0017444876572297345, 2.6487056465134826e-11)
# Si: -0.001260027797748667
# continue
# end inside
# ---Start cycle inside---
# c: 0.073202261720014
# g: [0.07320226 0.07320226 0.07320226 ... 0.07320226 0.07320226 0.07320226]
# idθ: [1470 1847 4036]
# θ[idθ]: [0.2941 0.3695 0.8073]
# Si_old_final: -0.001260027797748667
# Si_c: (-0.0015847269387909504, 2.6487056565961238e-11)
# Si: -0.0011595956809483162
# continue
# end inside
# ---Start cycle inside---
# c: 0.07300256082196552
# g: [0.07300256 0.07300256 0.07300256 ... 0.07300256 0.07300256 0.07300256]
# idθ: [1403 1938 4025]
# θ[idθ]: [0.2807 0.3877 0.8051]
# Si_old_final: -0.0011595956809483162
# Si_c: (-0.0014249662203521666, 2.6487056567391236e-11)
# Si: -0.0010559143346264624
# continue
# end inside
# ---Start cycle inside---
# c: 0.07280285992391704
# g: [0.07280286 0.07280286 0.07280286 ... 0.07280286 0.07280286 0.07280286]
# idθ: [1354 2013 4013]
# θ[idθ]: [0.2709 0.4027 0.8027]
# Si_old_final: -0.0010559143346264624
# Si_c: (-0.0012652055019133825, 2.648705643152603e-11)
# Si: -0.0009504216376490246
# continue
# end inside
# ---Start cycle inside---
# c: 0.07260315902586856
# g: [0.07260316 0.07260316 0.07260316 ... 0.07260316 0.07260316 0.07260316]
# idθ: [1314 2079 4001]
# θ[idθ]: [0.2629 0.4159 0.8003]
# Si_old_final: -0.0009504216376490246
# Si_c: (-0.0011054447834745987, 2.6487056567391236e-11)
# Si: -0.0008436394961202844
# continue
# end inside
# ---Start cycle inside---
# c: 0.07240345812782008
# g: [0.07240346 0.07240346 0.07240346 ... 0.07240346 0.07240346 0.07240346]
# idθ: [1279 2139 3988]
# θ[idθ]: [0.2559 0.4279 0.7977]
# Si_old_final: -0.0008436394961202844
# Si_c: (-0.0009456840650358148, 2.6487056432956027e-11)
# Si: -0.0007358744830113198
# continue
# end inside
# ---Start cycle inside---
# c: 0.0722037572297716
# g: [0.07220376 0.07220376 0.07220376 ... 0.07220376 0.07220376 0.07220376]
# idθ: [1249 2197 3974]
# θ[idθ]: [0.2499 0.4395 0.7949]
# Si_old_final: -0.0007358744830113198
# Si_c: (-0.0007859233465970307, 2.6487056514118055e-11)
# Si: -0.0006273392758694303
# continue
# end inside
# ---Start cycle inside---
# c: 0.07200405633172312
# g: [0.07200406 0.07200406 0.07200406 ... 0.07200406 0.07200406 0.07200406]
# idθ: [1221 2251 3960]
# θ[idθ]: [0.2443 0.4503 0.7921]
# Si_old_final: -0.0006273392758694303
# Si_c: (-0.000626162628158247, 2.6487056482654233e-11)
# Si: -0.0005181999054728665
# continue
# end inside
# ---Start cycle inside---
# c: 0.07180435543367464
# g: [0.07180436 0.07180436 0.07180436 ... 0.07180436 0.07180436 0.07180436]
# idθ: [1196 2304 3945]
# θ[idθ]: [0.2393 0.4609 0.7891]
# Si_old_final: -0.0005181999054728665
# Si_c: (-0.0004664019097194628, 2.6487056566676235e-11)
# Si: -0.0004085872740445902
# continue
# end inside
# ---Start cycle inside---
# c: 0.07160465453562616
# g: [0.07160465 0.07160465 0.07160465 ... 0.07160465 0.07160465 0.07160465]
# idθ: [1173 2356 3930]
# θ[idθ]: [0.2347 0.4713 0.7861]
# Si_old_final: -0.0004085872740445902
# Si_c: (-0.0003066411912806789, 2.6487056499458624e-11)
# Si: -0.0002986181702403716
# continue
# end inside
# ---Start cycle inside---
# c: 0.07140495363757768
# g: [0.07140495 0.07140495 0.07140495 ... 0.07140495 0.07140495 0.07140495]
# idθ: [1152 2408 3914]
# θ[idθ]: [0.2305 0.4817 0.7829]
# Si_old_final: -0.0002986181702403716
# Si_c: (-0.00014688047284189493, 2.6487056599570032e-11)
# Si: -0.00018839247639066792
# continue
# end inside
# ---Start cycle inside---
# c: 0.0712052527395292
# g: [0.07120525 0.07120525 0.07120525 ... 0.07120525 0.07120525 0.07120525]
# idθ: [1131 2458 3896]
# θ[idθ]: [0.2263 0.4917 0.7793]
# Si_old_final: -0.00018839247639066792
# Si_c: (1.2880245596888853e-05, 2.6487056397917234e-11)
# Si: -7.800516688464702e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.07100555184148072
# g: [0.07100555 0.07100555 0.07100555 ... 0.07100555 0.07100555 0.07100555]
# idθ: [1112 2509 3878]
# θ[idθ]: [0.2225 0.5019 0.7757]
# Si_old_final: -7.800516688464702e-05
# Si_c: (0.00017264096403567296, 2.6487056666430133e-11)
# Si: 3.245247345935342e-05
# search aP
# aP: 0.07100555184148072
# aP1_fin: 0.07100555184148072
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -7.800516688464702e-05
# -----!Si: 3.245247345935342e-05
# -----!aP_fin: 0.07100555184148072
# ----------------------------------------
# End
# -----------New--------------
# ********* T =134.0 ********
# max_x: 0.3224298632025059
# min_x: 0.6775701278344032
# f_max_x: 0.07229798279627002
# f_min_x: 0.06711154734205842
# f_h_maxi: -0.0001996970825888307
# [0.07229798 0.07209829 0.07189859 0.07169889 0.07149919 0.0712995
#  0.0710998  0.0709001  0.07070041 0.07050071 0.07030101 0.07010131
#  0.06990162 0.06970192 0.06950222 0.06930253 0.06910283 0.06890313
#  0.06870344 0.06850374 0.06830404 0.06810434 0.06790465 0.06770495
#  0.06750525 0.06730556]
# Lenth: 26
# ---Start cycle inside---
# c: 0.07229798279627002
# g: [0.07229798 0.07229798 0.07229798 ... 0.07229798 0.07229798 0.07229798]
# idθ: [1610 1612 4099]
# θ[idθ]: [0.3221 0.3225 0.8199]
# Si_old_final: 0
# Si_c: (-0.0019887550061364746, 2.5942514953254625e-11)
# Si: -0.0014608679492544006
# continue
# end inside
# ---Start cycle inside---
# c: 0.07209828571368118
# g: [0.07209829 0.07209829 0.07209829 ... 0.07209829 0.07209829 0.07209829]
# idθ: [1439 1806 4089]
# θ[idθ]: [0.2879 0.3613 0.8179]
# Si_old_final: -0.0014608679492544006
# Si_c: (-0.0018289973400654048, 2.5942514883241202e-11)
# Si: -0.0013570550272413427
# continue
# end inside
# ---Start cycle inside---
# c: 0.07189858863109234
# g: [0.07189859 0.07189859 0.07189859 ... 0.07189859 0.07189859 0.07189859]
# idθ: [1373 1895 4079]
# θ[idθ]: [0.2747 0.3791 0.8159]
# Si_old_final: -0.0013570550272413427
# Si_c: (-0.001669239673994335, 2.5942514883241202e-11)
# Si: -0.0012500251850499895
# continue
# end inside
# ---Start cycle inside---
# c: 0.07169889154850351
# g: [0.07169889 0.07169889 0.07169889 ... 0.07169889 0.07169889 0.07169889]
# idθ: [1325 1967 4068]
# θ[idθ]: [0.2651 0.3935 0.8137]
# Si_old_final: -0.0012500251850499895
# Si_c: (-0.0015094820079232653, 2.5942514884768488e-11)
# Si: -0.0011411805797019987
# continue
# end inside
# ---Start cycle inside---
# c: 0.07149919446591467
# g: [0.07149919 0.07149919 0.07149919 ... 0.07149919 0.07149919 0.07149919]
# idθ: [1285 2031 4057]
# θ[idθ]: [0.2571 0.4063 0.8115]
# Si_old_final: -0.0011411805797019987
# Si_c: (-0.0013497243418521955, 2.5942514884768488e-11)
# Si: -0.0010310289252469726
# continue
# end inside
# ---Start cycle inside---
# c: 0.07129949738332583
# g: [0.0712995 0.0712995 0.0712995 ... 0.0712995 0.0712995 0.0712995]
# idθ: [1252 2090 4046]
# θ[idθ]: [0.2505 0.4181 0.8093]
# Si_old_final: -0.0010310289252469726
# Si_c: (-0.0011899666757811257, 2.5942514852052725e-11)
# Si: -0.0009198655993310824
# continue
# end inside
# ---Start cycle inside---
# c: 0.071099800300737
# g: [0.0710998 0.0710998 0.0710998 ... 0.0710998 0.0710998 0.0710998]
# idθ: [1222 2144 4034]
# θ[idθ]: [0.2445 0.4289 0.8069]
# Si_old_final: -0.0009198655993310824
# Si_c: (-0.001030209009710056, 2.5942514989788676e-11)
# Si: -0.0008078958276615764
# continue
# end inside
# ---Start cycle inside---
# c: 0.07090010321814816
# g: [0.0709001 0.0709001 0.0709001 ... 0.0709001 0.0709001 0.0709001]
# idθ: [1195 2197 4022]
# θ[idθ]: [0.2391 0.4395 0.8045]
# Si_old_final: -0.0008078958276615764
# Si_c: (-0.000870451343638986, 2.5942514936133092e-11)
# Si: -0.0006952756975020257
# continue
# end inside
# ---Start cycle inside---
# c: 0.07070040613555932
# g: [0.07070041 0.07070041 0.07070041 ... 0.07070041 0.07070041 0.07070041]
# idθ: [1170 2248 4009]
# θ[idθ]: [0.2341 0.4497 0.8019]
# Si_old_final: -0.0006952756975020257
# Si_c: (-0.0007106936775679163, 2.5942514918247915e-11)
# Si: -0.0005821300068375742
# continue
# end inside
# ---Start cycle inside---
# c: 0.07050070905297048
# g: [0.07050071 0.07050071 0.07050071 ... 0.07050071 0.07050071 0.07050071]
# idθ: [1148 2297 3995]
# θ[idθ]: [0.2297 0.4595 0.7991]
# Si_old_final: -0.0005821300068375742
# Si_c: (-0.0005509360114968465, 2.5942514954018275e-11)
# Si: -0.00046856286882462775
# continue
# end inside
# ---Start cycle inside---
# c: 0.07030101197038165
# g: [0.07030101 0.07030101 0.07030101 ... 0.07030101 0.07030101 0.07030101]
# idθ: [1126 2346 3981]
# θ[idθ]: [0.2253 0.4693 0.7963]
# Si_old_final: -0.00046856286882462775
# Si_c: (-0.00039117834542577674, 2.5942514868410606e-11)
# Si: -0.0003546713029507597
# continue
# end inside
# ---Start cycle inside---
# c: 0.07010131488779281
# g: [0.07010131 0.07010131 0.07010131 ... 0.07010131 0.07010131 0.07010131]
# idθ: [1107 2393 3967]
# θ[idθ]: [0.2215 0.4787 0.7935]
# Si_old_final: -0.0003546713029507597
# Si_c: (-0.00023142067935470693, 2.5942514816664184e-11)
# Si: -0.00024053633503540146
# continue
# end inside
# ---Start cycle inside---
# c: 0.06990161780520397
# g: [0.06990162 0.06990162 0.06990162 ... 0.06990162 0.06990162 0.06990162]
# idθ: [1088 2441 3951]
# θ[idθ]: [0.2177 0.4883 0.7903]
# Si_old_final: -0.00024053633503540146
# Si_c: (-7.166301328363712e-05, 2.5942514988261355e-11)
# Si: -0.00012623597100761054
# continue
# end inside
# ---Start cycle inside---
# c: 0.06970192072261513
# g: [0.06970192 0.06970192 0.06970192 ... 0.06970192 0.06970192 0.06970192]
# idθ: [1071 2488 3935]
# θ[idθ]: [0.2143 0.4977 0.7871]
# Si_old_final: -0.00012623597100761054
# Si_c: (8.809465278743266e-05, 2.5942515022122588e-11)
# Si: -1.1846349480042272e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.0695022236400263
# g: [0.06950222 0.06950222 0.06950222 ... 0.06950222 0.06950222 0.06950222]
# idθ: [1054 2536 3918]
# θ[idθ]: [0.2109 0.5073 0.7837]
# Si_old_final: -1.1846349480042272e-05
# Si_c: (0.00024785231885850244, 2.5942514919202472e-11)
# Si: 0.0001025595017092246
# search aP
# aP: 0.0695022236400263
# aP2_fin: 0.06970192072261513
# Flag2 == True
# break
# ----------------------------------------
# -----!Si_old_final: -1.1846349480042272e-05
# -----!Si: 0.0001025595017092246
# -----!aP_fin: 0.06970192072261513
# ----------------------------------------
# End
# -----------New--------------
# ********* T =133.0 ********
# max_x: 0.31563653078974413
# min_x: 0.6843634508780242
# f_max_x: 0.07120755851362699
# f_min_x: 0.06546335586627706
# f_h_maxi: -0.00019969318411340177
# [0.07120756 0.07100787 0.07080817 0.07060848 0.07040879 0.07020909
#  0.0700094  0.06980971 0.06961001 0.06941032 0.06921063 0.06901093
#  0.06881124 0.06861155 0.06841185 0.06821216 0.06801247 0.06781277
#  0.06761308 0.06741339 0.06721369 0.067014   0.06681431 0.06661462
#  0.06641492 0.06621523 0.06601554 0.06581584 0.06561615]
# Lenth: 29
# ---Start cycle inside---
# c: 0.07120755851362699
# g: [0.07120756 0.07120756 0.07120756 ... 0.07120756 0.07120756 0.07120756]
# idθ: [1576 1578 4147]
# θ[idθ]: [0.3153 0.3157 0.8295]
# Si_old_final: 0
# Si_c: (-0.0022354645607922195, 2.5433887552383737e-11)
# Si: -0.001672672241405472
# continue
# end inside
# ---Start cycle inside---
# c: 0.07100786532951359
# g: [0.07100787 0.07100787 0.07100787 ... 0.07100787 0.07100787 0.07100787]
# idθ: [1409 1768 4138]
# θ[idθ]: [0.2819 0.3537 0.8277]
# Si_old_final: -0.001672672241405472
# Si_c: (-0.0020757100135014948, 2.5433887552383737e-11)
# Si: -0.0015656625890039905
# continue
# end inside
# ---Start cycle inside---
# c: 0.07080817214540018
# g: [0.07080817 0.07080817 0.07080817 ... 0.07080817 0.07080817 0.07080817]
# idθ: [1344 1854 4129]
# θ[idθ]: [0.2689 0.3709 0.8259]
# Si_old_final: -0.0015656625890039905
# Si_c: (-0.00191595546621077, 2.5433887690524738e-11)
# Si: -0.0014554703981848177
# continue
# end inside
# ---Start cycle inside---
# c: 0.07060847896128677
# g: [0.07060848 0.07060848 0.07060848 ... 0.07060848 0.07060848 0.07060848]
# idθ: [1297 1924 4119]
# θ[idθ]: [0.2595 0.3849 0.8239]
# Si_old_final: -0.0014554703981848177
# Si_c: (-0.0017562009189200454, 2.543388755074882e-11)
# Si: -0.0013434642948183756
# continue
# end inside
# ---Start cycle inside---
# c: 0.07040878577717337
# g: [0.07040879 0.07040879 0.07040879 ... 0.07040879 0.07040879 0.07040879]
# idθ: [1258 1986 4110]
# θ[idθ]: [0.2517 0.3973 0.8221]
# Si_old_final: -0.0013434642948183756
# Si_c: (-0.0015964463716293205, 2.543388762063678e-11)
# Si: -0.0012301416400034393
# continue
# end inside
# ---Start cycle inside---
# c: 0.07020909259305996
# g: [0.07020909 0.07020909 0.07020909 ... 0.07020909 0.07020909 0.07020909]
# idθ: [1225 2043 4099]
# θ[idθ]: [0.2451 0.4087 0.8199]
# Si_old_final: -0.0012301416400034393
# Si_c: (-0.001436691824338596, 2.5433887552383737e-11)
# Si: -0.001115784302902479
# continue
# end inside
# ---Start cycle inside---
# c: 0.07000939940894656
# g: [0.0700094 0.0700094 0.0700094 ... 0.0700094 0.0700094 0.0700094]
# idθ: [1196 2096 4089]
# θ[idθ]: [0.2393 0.4193 0.8179]
# Si_old_final: -0.001115784302902479
# Si_c: (-0.0012769372770478713, 2.5433887551566276e-11)
# Si: -0.0010005962161505496
# continue
# end inside
# ---Start cycle inside---
# c: 0.06980970622483315
# g: [0.06980971 0.06980971 0.06980971 ... 0.06980971 0.06980971 0.06980971]
# idθ: [1169 2146 4078]
# θ[idθ]: [0.2339 0.4293 0.8157]
# Si_old_final: -0.0010005962161505496
# Si_c: (-0.0011171827297571464, 2.5433887480860874e-11)
# Si: -0.0008847227796383057
# continue
# end inside
# ---Start cycle inside---
# c: 0.06961001304071975
# g: [0.06961001 0.06961001 0.06961001 ... 0.06961001 0.06961001 0.06961001]
# idθ: [1145 2195 4067]
# θ[idθ]: [0.2291 0.4391 0.8135]
# Si_old_final: -0.0008847227796383057
# Si_c: (-0.0009574281824664219, 2.543388748167833e-11)
# Si: -0.0007682841200213169
# continue
# end inside
# ---Start cycle inside---
# c: 0.06941031985660634
# g: [0.06941032 0.06941032 0.06941032 ... 0.06941032 0.06941032 0.06941032]
# idθ: [1123 2242 4055]
# θ[idθ]: [0.2247 0.4485 0.8111]
# Si_old_final: -0.0007682841200213169
# Si_c: (-0.000797673635175697, 2.543388751580484e-11)
# Si: -0.0006513789464043373
# continue
# end inside
# ---Start cycle inside---
# c: 0.06921062667249293
# g: [0.06921063 0.06921063 0.06921063 ... 0.06921063 0.06921063 0.06921063]
# idθ: [1102 2289 4043]
# θ[idθ]: [0.2205 0.4579 0.8087]
# Si_old_final: -0.0006513789464043373
# Si_c: (-0.0006379190878849725, 2.5433887552383737e-11)
# Si: -0.0005340952972428289
# continue
# end inside
# ---Start cycle inside---
# c: 0.06901093348837953
# g: [0.06901093 0.06901093 0.06901093 ... 0.06901093 0.06901093 0.06901093]
# idθ: [1083 2334 4030]
# θ[idθ]: [0.2167 0.4669 0.8061]
# Si_old_final: -0.0005340952972428289
# Si_c: (-0.0004781645405942478, 2.5433887551566276e-11)
# Si: -0.00041650780436294684
# continue
# end inside
# ---Start cycle inside---
# c: 0.06881124030426612
# g: [0.06881124 0.06881124 0.06881124 ... 0.06881124 0.06881124 0.06881124]
# idθ: [1064 2379 4017]
# θ[idθ]: [0.2129 0.4759 0.8035]
# Si_old_final: -0.00041650780436294684
# Si_c: (-0.00031840999330352306, 2.543388748045215e-11)
# Si: -0.0002986901203437709
# continue
# end inside
# ---Start cycle inside---
# c: 0.06861154712015272
# g: [0.06861155 0.06861155 0.06861155 ... 0.06861155 0.06861155 0.06861155]
# idθ: [1047 2424 4003]
# θ[idθ]: [0.2095 0.4849 0.8007]
# Si_old_final: -0.0002986901203437709
# Si_c: (-0.00015865544601279842, 2.543388758834955e-11)
# Si: -0.0001807041176627336
# continue
# end inside
# ---Start cycle inside---
# c: 0.06841185393603931
# g: [0.06841185 0.06841185 0.06841185 ... 0.06841185 0.06841185 0.06841185]
# idθ: [1031 2469 3988]
# θ[idθ]: [0.2063 0.4939 0.7977]
# Si_old_final: -0.0001807041176627336
# Si_c: (1.0991012779262691e-06, 2.5433887517644122e-11)
# Si: -6.261412301528334e-05
# continue
# end inside
# ---Start cycle inside---
# c: 0.0682121607519259
# g: [0.06821216 0.06821216 0.06821216 ... 0.06821216 0.06821216 0.06821216]
# idθ: [1015 2513 3973]
# θ[idθ]: [0.2031 0.5027 0.7947]
# Si_old_final: -6.261412301528334e-05
# Si_c: (0.00016085364856865104, 2.5433887517848488e-11)
# Si: 5.5515381660383866e-05
# search aP
# aP: 0.0682121607519259
# aP1_fin: 0.0682121607519259
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -6.261412301528334e-05
# -----!Si: 5.5515381660383866e-05
# -----!aP_fin: 0.0682121607519259
# ----------------------------------------
# End
# -----------New--------------
# ********* T =132.0 ********
# max_x: 0.30909061276883554
# min_x: 0.6909093806564794
# f_max_x: 0.07013010950523024
# f_min_x: 0.06382005131265342
# f_h_maxi: -0.00019968919997285026
# [0.07013011 0.06993042 0.06973073 0.06953104 0.06933135 0.06913166
#  0.06893197 0.06873229 0.0685326  0.06833291 0.06813322 0.06793353
#  0.06773384 0.06753415 0.06733446 0.06713477 0.06693508 0.06673539
#  0.0665357  0.06633601 0.06613633 0.06593664 0.06573695 0.06553726
#  0.06533757 0.06513788 0.06493819 0.0647385  0.06453881 0.06433912
#  0.06413943 0.06393974]
# Lenth: 32
# ---Start cycle inside---
# c: 0.07013010950523024
# g: [0.07013011 0.07013011 0.07013011 ... 0.07013011 0.07013011 0.07013011]
# idθ: [1543 1545 4192]
# θ[idθ]: [0.3087 0.3091 0.8385]
# Si_old_final: 0
# Si_c: (-0.0024840300596740642, 2.4964058799414638e-11)
# Si: -0.001894664457462348
# continue
# end inside
# ---Start cycle inside---
# c: 0.0699304203052574
# g: [0.06993042 0.06993042 0.06993042 ... 0.06993042 0.06993042 0.06993042]
# idθ: [1379 1731 4184]
# θ[idθ]: [0.2759 0.3463 0.8369]
# Si_old_final: -0.001894664457462348
# Si_c: (-0.002324278699695787, 2.4964058654774382e-11)
# Si: -0.001784623567902684
# continue
# end inside
# ---Start cycle inside---
# c: 0.06973073110528455
# g: [0.06973073 0.06973073 0.06973073 ... 0.06973073 0.06973073 0.06973073]
# idθ: [1316 1815 4176]
# θ[idθ]: [0.2633 0.3631 0.8353]
# Si_old_final: -0.001784623567902684
# Si_c: (-0.0021645273397175096, 2.496405880116638e-11)
# Si: -0.0016714346791387145
# continue
# end inside
# ---Start cycle inside---
# c: 0.0695310419053117
# g: [0.06953104 0.06953104 0.06953104 ... 0.06953104 0.06953104 0.06953104]
# idθ: [1270 1883 4167]
# θ[idθ]: [0.2541 0.3767 0.8335]
# Si_old_final: -0.0016714346791387145
# Si_c: (-0.0020047759797392323, 2.4964058658277844e-11)
# Si: -0.0015564377215853398
# continue
# end inside
# ---Start cycle inside---
# c: 0.06933135270533886
# g: [0.06933135 0.06933135 0.06933135 ... 0.06933135 0.06933135 0.06933135]
# idθ: [1232 1944 4158]
# θ[idθ]: [0.2465 0.3889 0.8317]
# Si_old_final: -0.0015564377215853398
# Si_c: (-0.0018450246197609546, 2.4964058654774382e-11)
# Si: -0.0014401154575791537
# continue
# end inside
# ---Start cycle inside---
# c: 0.06913166350536601
# g: [0.06913166 0.06913166 0.06913166 ... 0.06913166 0.06913166 0.06913166]
# idθ: [1199 1998 4149]
# θ[idθ]: [0.2399 0.3997 0.8299]
# Si_old_final: -0.0014401154575791537
# Si_c: (-0.0016852732597826773, 2.4964058799414638e-11)
# Si: -0.0013227488823287148
# continue
# end inside
# ---Start cycle inside---
# c: 0.06893197430539316
# g: [0.06893197 0.06893197 0.06893197 ... 0.06893197 0.06893197 0.06893197]
# idθ: [1170 2050 4140]
# θ[idθ]: [0.2341 0.4101 0.8281]
# Si_old_final: -0.0013227488823287148
# Si_c: (-0.0015255218998044, 2.4964058798538776e-11)
# Si: -0.001204529365963397
# continue
# end inside
# ---Start cycle inside---
# c: 0.06873228510542032
# g: [0.06873229 0.06873229 0.06873229 ... 0.06873229 0.06873229 0.06873229]
# idθ: [1144 2099 4130]
# θ[idθ]: [0.2289 0.4199 0.8261]
# Si_old_final: -0.001204529365963397
# Si_c: (-0.0013657705398261227, 2.4964058799414638e-11)
# Si: -0.0010855987490256684
# continue
# end inside
# ---Start cycle inside---
# c: 0.06853259590544747
# g: [0.0685326 0.0685326 0.0685326 ... 0.0685326 0.0685326 0.0685326]
# idθ: [1121 2146 4120]
# θ[idθ]: [0.2243 0.4293 0.8241]
# Si_old_final: -0.0010855987490256684
# Si_c: (-0.0012060191798478452, 2.4964058798538776e-11)
# Si: -0.0009660726344698556
# continue
# end inside
# ---Start cycle inside---
# c: 0.06833290670547462
# g: [0.06833291 0.06833291 0.06833291 ... 0.06833291 0.06833291 0.06833291]
# idθ: [1099 2192 4110]
# θ[idθ]: [0.2199 0.4385 0.8221]
# Si_old_final: -0.0009660726344698556
# Si_c: (-0.0010462678198695679, 2.4964058727094515e-11)
# Si: -0.0008460467455968341
# continue
# end inside
# ---Start cycle inside---
# c: 0.06813321750550178
# g: [0.06813322 0.06813322 0.06813322 ... 0.06813322 0.06813322 0.06813322]
# idθ: [1078 2236 4099]
# θ[idθ]: [0.2157 0.4473 0.8199]
# Si_old_final: -0.0008460467455968341
# Si_c: (-0.0008865164598912904, 2.4964058654774382e-11)
# Si: -0.0007256013460960436
# continue
# end inside
# ---Start cycle inside---
# c: 0.06793352830552893
# g: [0.06793353 0.06793353 0.06793353 ... 0.06793353 0.06793353 0.06793353]
# idθ: [1059 2280 4088]
# θ[idθ]: [0.2119 0.4561 0.8177]
# Si_old_final: -0.0007256013460960436
# Si_c: (-0.0007267650999130129, 2.4964058798538776e-11)
# Si: -0.0006048077441921701
# continue
# end inside
# ---Start cycle inside---
# c: 0.06773383910555608
# g: [0.06773384 0.06773384 0.06773384 ... 0.06773384 0.06773384 0.06773384]
# idθ: [1041 2323 4076]
# θ[idθ]: [0.2083 0.4647 0.8153]
# Si_old_final: -0.0006048077441921701
# Si_c: (-0.0005670137399347356, 2.4964058727532446e-11)
# Si: -0.00048373060547432354
# continue
# end inside
# ---Start cycle inside---
# c: 0.06753414990558324
# g: [0.06753415 0.06753415 0.06753415 ... 0.06753415 0.06753415 0.06753415]
# idθ: [1024 2365 4064]
# θ[idθ]: [0.2049 0.4731 0.8129]
# Si_old_final: -0.00048373060547432354
# Si_c: (-0.00040726237995645815, 2.496405872731348e-11)
# Si: -0.00036243088075915095
# continue
# end inside
# ---Start cycle inside---
# c: 0.06733446070561039
# g: [0.06733446 0.06733446 0.06733446 ... 0.06733446 0.06733446 0.06733446]
# idθ: [1008 2408 4051]
# θ[idθ]: [0.2017 0.4817 0.8103]
# Si_old_final: -0.00036243088075915095
# Si_c: (-0.00024751101997818074, 2.4964058833604013e-11)
# ...
#  0.00345504 0.00325644 0.00305784 0.00285924 0.00266064 0.00246204
#  0.00226344 0.00206484 0.00186624 0.00166764 0.00146904 0.00127044
#  0.00107185 0.00087325 0.00067465]
# Lenth: 69
# ---Start cycle inside---
# c: 0.014179397440028892
# g: [0.0141794 0.0141794 0.0141794 ... 0.0141794 0.0141794 0.0141794]
# idθ: [ 272  274 4996]
# θ[idθ]: [0.0545 0.0549 0.9993]
# Si_old_final: 0
# Si_c: (-0.008128633684668927, 7.961101388103219e-10)
# Si: -0.009478369782312613
# continue
# end inside
# ---Start cycle inside---
# c: 0.01398079816173666
# g: [0.0139808 0.0139808 0.0139808 ... 0.0139808 0.0139808 0.0139808]
# idθ: [ 217  342 4996]
# θ[idθ]: [0.0435 0.0685 0.9993]
# Si_old_final: -0.009478369782312613
# Si_c: (-0.007969754262035143, 7.961101418155546e-10)
# Si: -0.00928927689644597
# continue
# end inside
# ---Start cycle inside---
# c: 0.013782198883444428
# g: [0.0137822 0.0137822 0.0137822 ... 0.0137822 0.0137822 0.0137822]
# idθ: [ 197  375 4996]
# θ[idθ]: [0.0395 0.0751 0.9993]
# Si_old_final: -0.00928927689644597
# Si_c: (-0.007810874839401356, 7.961101418155546e-10)
# Si: -0.009099054867416207
# continue
# end inside
# ---Start cycle inside---
# c: 0.013583599605152196
# g: [0.0135836 0.0135836 0.0135836 ... 0.0135836 0.0135836 0.0135836]
# idθ: [ 183  403 4996]
# θ[idθ]: [0.0367 0.0807 0.9993]
# Si_old_final: -0.009099054867416207
# Si_c: (-0.00765199541676757, 7.961101388103217e-10)
# Si: -0.008908162423270388
# continue
# end inside
# ---Start cycle inside---
# c: 0.013385000326859964
# g: [0.013385 0.013385 0.013385 ... 0.013385 0.013385 0.013385]
# idθ: [ 171  429 4996]
# θ[idθ]: [0.0343 0.0859 0.9993]
# Si_old_final: -0.008908162423270388
# Si_c: (-0.007493115994133784, 7.961101388103217e-10)
# Si: -0.008716760707521374
# continue
# end inside
# ---Start cycle inside---
# c: 0.013186401048567732
# g: [0.0131864 0.0131864 0.0131864 ... 0.0131864 0.0131864 0.0131864]
# idθ: [ 161  453 4996]
# θ[idθ]: [0.0323 0.0907 0.9993]
# Si_old_final: -0.008716760707521374
# Si_c: (-0.007334236571499998, 7.961101388103217e-10)
# Si: -0.008524939656409932
# continue
# end inside
# ---Start cycle inside---
# c: 0.0129878017702755
# g: [0.0129878 0.0129878 0.0129878 ... 0.0129878 0.0129878 0.0129878]
# idθ: [ 153  476 4996]
# θ[idθ]: [0.0307 0.0953 0.9993]
# Si_old_final: -0.008524939656409932
# Si_c: (-0.007175357148866213, 7.961101388103217e-10)
# Si: -0.008332756668002279
# continue
# end inside
# ---Start cycle inside---
# c: 0.012789202491983268
# g: [0.0127892 0.0127892 0.0127892 ... 0.0127892 0.0127892 0.0127892]
# idθ: [ 145  498 4996]
# θ[idθ]: [0.0291 0.0997 0.9993]
# Si_old_final: -0.008332756668002279
# Si_c: (-0.007016477726232428, 7.961101388103217e-10)
# Si: -0.008140260662515443
# continue
# end inside
# ---Start cycle inside---
# c: 0.012590603213691036
# g: [0.0125906 0.0125906 0.0125906 ... 0.0125906 0.0125906 0.0125906]
# idθ: [ 139  520 4996]
# θ[idθ]: [0.0279 0.1041 0.9993]
# Si_old_final: -0.008140260662515443
# Si_c: (-0.006857598303598643, 7.961101418155546e-10)
# Si: -0.007947477338424335
# continue
# end inside
# ---Start cycle inside---
# c: 0.012392003935398804
# g: [0.012392 0.012392 0.012392 ... 0.012392 0.012392 0.012392]
# idθ: [ 132  542 4996]
# θ[idθ]: [0.0265 0.1085 0.9993]
# Si_old_final: -0.007947477338424335
# Si_c: (-0.006698718880964858, 7.961101418155546e-10)
# Si: -0.007754442673722359
# continue
# end inside
# ---Start cycle inside---
# c: 0.012193404657106572
# g: [0.0121934 0.0121934 0.0121934 ... 0.0121934 0.0121934 0.0121934]
# idθ: [ 127  563 4996]
# θ[idθ]: [0.0255 0.1127 0.9993]
# Si_old_final: -0.007754442673722359
# Si_c: (-0.0065398394583310706, 7.961101388103217e-10)
# Si: -0.007561166652250346
# continue
# end inside
# ---Start cycle inside---
# c: 0.01199480537881434
# g: [0.01199481 0.01199481 0.01199481 ... 0.01199481 0.01199481 0.01199481]
# idθ: [ 122  585 4995]
# θ[idθ]: [0.0245 0.1171 0.9991]
# Si_old_final: -0.007561166652250346
# Si_c: (-0.006380960035697287, 7.961101418155546e-10)
# Si: -0.007367409463814016
# continue
# end inside
# ---Start cycle inside---
# c: 0.011796206100522108
# g: [0.01179621 0.01179621 0.01179621 ... 0.01179621 0.01179621 0.01179621]
# idθ: [ 117  607 4995]
# θ[idθ]: [0.0235 0.1215 0.9991]
# Si_old_final: -0.007367409463814016
# Si_c: (-0.0062220806130635, 7.961101358050892e-10)
# Si: -0.007173756428523544
# continue
# end inside
# ---Start cycle inside---
# c: 0.011597606822229876
# g: [0.01159761 0.01159761 0.01159761 ... 0.01159761 0.01159761 0.01159761]
# idθ: [ 112  629 4995]
# θ[idθ]: [0.0225 0.1259 0.9991]
# Si_old_final: -0.007173756428523544
# Si_c: (-0.006063201190429715, 7.961101418155546e-10)
# Si: -0.006979915218622298
# continue
# end inside
# ---Start cycle inside---
# c: 0.011399007543937644
# g: [0.01139901 0.01139901 0.01139901 ... 0.01139901 0.01139901 0.01139901]
# idθ: [ 108  650 4995]
# θ[idθ]: [0.0217 0.1301 0.9991]
# Si_old_final: -0.006979915218622298
# Si_c: (-0.00590432176779593, 7.961101418155546e-10)
# Si: -0.006785894334885993
# continue
# end inside
# ---Start cycle inside---
# c: 0.011200408265645412
# g: [0.01120041 0.01120041 0.01120041 ... 0.01120041 0.01120041 0.01120041]
# idθ: [ 104  673 4995]
# θ[idθ]: [0.0209 0.1347 0.9991]
# Si_old_final: -0.006785894334885993
# Si_c: (-0.005745442345162143, 7.961101388103217e-10)
# Si: -0.0065917066391721485
# continue
# end inside
# ---Start cycle inside---
# c: 0.01100180898735318
# g: [0.01100181 0.01100181 0.01100181 ... 0.01100181 0.01100181 0.01100181]
# idθ: [ 100  695 4995]
# θ[idθ]: [0.0201 0.1391 0.9991]
# Si_old_final: -0.0065917066391721485
# Si_c: (-0.005586562922528358, 7.961101373077058e-10)
# Si: -0.0063973603894618425
# continue
# end inside
# ---Start cycle inside---
# c: 0.010803209709060948
# g: [0.01080321 0.01080321 0.01080321 ... 0.01080321 0.01080321 0.01080321]
# idθ: [  96  718 4995]
# θ[idθ]: [0.0193 0.1437 0.9991]
# Si_old_final: -0.0063973603894618425
# Si_c: (-0.005427683499894572, 7.961101373077057e-10)
# Si: -0.006202864256002823
# continue
# end inside
# ---Start cycle inside---
# c: 0.010604610430768716
# g: [0.01060461 0.01060461 0.01060461 ... 0.01060461 0.01060461 0.01060461]
# idθ: [  92  741 4995]
# θ[idθ]: [0.0185 0.1483 0.9991]
# Si_old_final: -0.006202864256002823
# Si_c: (-0.005268804077260787, 7.961101403129382e-10)
# Si: -0.006008227345431228
# continue
# end inside
# ---Start cycle inside---
# c: 0.010406011152476484
# g: [0.01040601 0.01040601 0.01040601 ... 0.01040601 0.01040601 0.01040601]
# idθ: [  89  764 4995]
# θ[idθ]: [0.0179 0.1529 0.9991]
# Si_old_final: -0.006008227345431228
# Si_c: (-0.005109924654627001, 7.961101388103217e-10)
# Si: -0.005813446612661185
# continue
# end inside
# ---Start cycle inside---
# c: 0.010207411874184252
# g: [0.01020741 0.01020741 0.01020741 ... 0.01020741 0.01020741 0.01020741]
# idθ: [  86  788 4995]
# θ[idθ]: [0.0173 0.1577 0.9991]
# Si_old_final: -0.005813446612661185
# Si_c: (-0.004951045231993216, 7.961101403129382e-10)
# Si: -0.005618536701728603
# continue
# end inside
# ---Start cycle inside---
# c: 0.01000881259589202
# g: [0.01000881 0.01000881 0.01000881 ... 0.01000881 0.01000881 0.01000881]
# idθ: [  83  812 4995]
# θ[idθ]: [0.0167 0.1625 0.9991]
# Si_old_final: -0.005618536701728603
# Si_c: (-0.0047921658093594294, 7.961101388103217e-10)
# Si: -0.005423501990850972
# continue
# end inside
# ---Start cycle inside---
# c: 0.009810213317599788
# g: [0.00981021 0.00981021 0.00981021 ... 0.00981021 0.00981021 0.00981021]
# idθ: [  80  837 4995]
# θ[idθ]: [0.0161 0.1675 0.9991]
# Si_old_final: -0.005423501990850972
# Si_c: (-0.004633286386725645, 7.961101403129382e-10)
# Si: -0.005228347027475694
# continue
# end inside
# ---Start cycle inside---
# c: 0.009611614039307556
# g: [0.00961161 0.00961161 0.00961161 ... 0.00961161 0.00961161 0.00961161]
# idθ: [  77  862 4995]
# θ[idθ]: [0.0155 0.1725 0.9991]
# Si_old_final: -0.005228347027475694
# Si_c: (-0.004474406964091859, 7.961101388103217e-10)
# Si: -0.005033076536009662
# continue
# end inside
# ---Start cycle inside---
# c: 0.009413014761015324
# g: [0.00941301 0.00941301 0.00941301 ... 0.00941301 0.00941301 0.00941301]
# idθ: [  74  888 4994]
# θ[idθ]: [0.0149 0.1777 0.9989]
# Si_old_final: -0.005033076536009662
# Si_c: (-0.004315527541458073, 7.961101388103217e-10)
# Si: -0.004837527578331807
# continue
# end inside
# ---Start cycle inside---
# c: 0.009214415482723093
# g: [0.00921442 0.00921442 0.00921442 ... 0.00921442 0.00921442 0.00921442]
# idθ: [  71  915 4994]
# θ[idθ]: [0.0143 0.1831 0.9989]
# Si_old_final: -0.004837527578331807
# Si_c: (-0.004156648118824288, 7.961101388103217e-10)
# Si: -0.004642080672800085
# continue
# end inside
# ---Start cycle inside---
# c: 0.00901581620443086
# g: [0.00901582 0.00901582 0.00901582 ... 0.00901582 0.00901582 0.00901582]
# idθ: [  69  942 4994]
# θ[idθ]: [0.0139 0.1885 0.9989]
# Si_old_final: -0.004642080672800085
# Si_c: (-0.003997768696190502, 7.961101388103217e-10)
# Si: -0.004446519964729168
# continue
# end inside
# ---Start cycle inside---
# c: 0.008817216926138629
# g: [0.00881722 0.00881722 0.00881722 ... 0.00881722 0.00881722 0.00881722]
# idθ: [  66  969 4994]
# θ[idθ]: [0.0133 0.1939 0.9989]
# Si_old_final: -0.004446519964729168
# Si_c: (-0.0038388892735567158, 7.961101388103217e-10)
# Si: -0.004250869376054688
# continue
# end inside
# ---Start cycle inside---
# c: 0.008618617647846397
# g: [0.00861862 0.00861862 0.00861862 ... 0.00861862 0.00861862 0.00861862]
# idθ: [  64  998 4994]
# θ[idθ]: [0.0129 0.1997 0.9989]
# Si_old_final: -0.004250869376054688
# Si_c: (-0.003680009850922931, 7.961101403129382e-10)
# Si: -0.004055111834511425
# continue
# end inside
# ---Start cycle inside---
# c: 0.008420018369554165
# g: [0.00842002 0.00842002 0.00842002 ... 0.00842002 0.00842002 0.00842002]
# idθ: [  62 1027 4994]
# θ[idθ]: [0.0125 0.2055 0.9989]
# Si_old_final: -0.004055111834511425
# Si_c: (-0.0035211304282891445, 7.961101388103217e-10)
# Si: -0.003859262668238732
# continue
# end inside
# ---Start cycle inside---
# c: 0.008221419091261933
# g: [0.00822142 0.00822142 0.00822142 ... 0.00822142 0.00822142 0.00822142]
# idθ: [  59 1057 4994]
# θ[idθ]: [0.0119 0.2115 0.9989]
# Si_old_final: -0.003859262668238732
# Si_c: (-0.00336225100565536, 7.961101403129382e-10)
# Si: -0.0036633297769618147
# continue
# end inside
# ---Start cycle inside---
# c: 0.0080228198129697
# g: [0.00802282 0.00802282 0.00802282 ... 0.00802282 0.00802282 0.00802282]
# idθ: [  57 1088 4994]
# θ[idθ]: [0.0115 0.2177 0.9989]
# Si_old_final: -0.0036633297769618147
# Si_c: (-0.003203371583021574, 7.961101388103217e-10)
# Si: -0.0034672991697892834
# continue
# end inside
# ---Start cycle inside---
# c: 0.007824220534677469
# g: [0.00782422 0.00782422 0.00782422 ... 0.00782422 0.00782422 0.00782422]
# idθ: [  55 1120 4994]
# θ[idθ]: [0.0111 0.2241 0.9989]
# Si_old_final: -0.0034672991697892834
# Si_c: (-0.0030444921603877883, 7.961101380590138e-10)
# Si: -0.003271183388609407
# continue
# end inside
# ---Start cycle inside---
# c: 0.007625621256385237
# g: [0.00762562 0.00762562 0.00762562 ... 0.00762562 0.00762562 0.00762562]
# idθ: [  53 1153 4993]
# θ[idθ]: [0.0107 0.2307 0.9987]
# Si_old_final: -0.003271183388609407
# Si_c: (-0.002885612737754003, 7.961101403129382e-10)
# Si: -0.003074896677096149
# continue
# end inside
# ---Start cycle inside---
# c: 0.007427021978093005
# g: [0.00742702 0.00742702 0.00742702 ... 0.00742702 0.00742702 0.00742702]
# idθ: [  51 1186 4993]
# θ[idθ]: [0.0103 0.2373 0.9987]
# Si_old_final: -0.003074896677096149
# Si_c: (-0.002726733315120217, 7.961101388103217e-10)
# Si: -0.002878656194943906
# continue
# end inside
# ---Start cycle inside---
# c: 0.007228422699800773
# g: [0.00722842 0.00722842 0.00722842 ... 0.00722842 0.00722842 0.00722842]
# idθ: [  49 1221 4993]
# θ[idθ]: [0.0099 0.2443 0.9987]
# Si_old_final: -0.002878656194943906
# Si_c: (-0.0025678538924864317, 7.961101388103217e-10)
# Si: -0.002682336575835003
# continue
# end inside
# ---Start cycle inside---
# c: 0.007029823421508541
# g: [0.00702982 0.00702982 0.00702982 ... 0.00702982 0.00702982 0.00702982]
# idθ: [  47 1257 4993]
# θ[idθ]: [0.0095 0.2515 0.9987]
# Si_old_final: -0.002682336575835003
# Si_c: (-0.0024089744698526463, 7.961101388103217e-10)
# Si: -0.002485939945034287
# continue
# end inside
# ---Start cycle inside---
# c: 0.006831224143216309
# g: [0.00683122 0.00683122 0.00683122 ... 0.00683122 0.00683122 0.00683122]
# idθ: [  45 1295 4993]
# θ[idθ]: [0.0091 0.2591 0.9987]
# Si_old_final: -0.002485939945034287
# Si_c: (-0.0022500950472188605, 7.961101388103217e-10)
# Si: -0.0022894684874251313
# continue
# end inside
# ---Start cycle inside---
# c: 0.006632624864924077
# g: [0.00663262 0.00663262 0.00663262 ... 0.00663262 0.00663262 0.00663262]
# idθ: [  43 1333 4992]
# θ[idθ]: [0.0087 0.2667 0.9985]
# Si_old_final: -0.0022894684874251313
# Si_c: (-0.0020912156245850755, 7.961101403129382e-10)
# Si: -0.0020928377422802804
# continue
# end inside
# ---Start cycle inside---
# c: 0.006434025586631845
# g: [0.00643403 0.00643403 0.00643403 ... 0.00643403 0.00643403 0.00643403]
# idθ: [  41 1373 4992]
# θ[idθ]: [0.0083 0.2747 0.9985]
# Si_old_final: -0.0020928377422802804
# Si_c: (-0.0019323362019512897, 7.961101395616301e-10)
# Si: -0.0018962631541729492
# continue
# end inside
# ---Start cycle inside---
# c: 0.006235426308339613
# g: [0.00623543 0.00623543 0.00623543 ... 0.00623543 0.00623543 0.00623543]
# idθ: [  40 1415 4992]
# θ[idθ]: [0.0081 0.2831 0.9985]
# Si_old_final: -0.0018962631541729492
# Si_c: (-0.001773456779317504, 7.961101395616301e-10)
# Si: -0.0016996038861443541
# continue
# end inside
# ---Start cycle inside---
# c: 0.006036827030047381
# g: [0.00603683 0.00603683 0.00603683 ... 0.00603683 0.00603683 0.00603683]
# idθ: [  38 1458 4992]
# θ[idθ]: [0.0077 0.2917 0.9985]
# Si_old_final: -0.0016996038861443541
# Si_c: (-0.0016145773566837184, 7.961101395616301e-10)
# Si: -0.0015028886495636142
# continue
# end inside
# ---Start cycle inside---
# c: 0.005838227751755149
# g: [0.00583823 0.00583823 0.00583823 ... 0.00583823 0.00583823 0.00583823]
# idθ: [  36 1502 4992]
# θ[idθ]: [0.0073 0.3005 0.9985]
# Si_old_final: -0.0015028886495636142
# Si_c: (-0.0014556979340499326, 7.961101391859763e-10)
# Si: -0.0013061092118212944
# continue
# end inside
# ---Start cycle inside---
# c: 0.005639628473462917
# g: [0.00563963 0.00563963 0.00563963 ... 0.00563963 0.00563963 0.00563963]
# idθ: [  35 1549 4991]
# θ[idθ]: [0.0071 0.3099 0.9983]
# Si_old_final: -0.0013061092118212944
# Si_c: (-0.0012968185114161474, 7.961101399372843e-10)
# Si: -0.0011092144960134197
# continue
# end inside
# ---Start cycle inside---
# c: 0.005441029195170685
# g: [0.00544103 0.00544103 0.00544103 ... 0.00544103 0.00544103 0.00544103]
# idθ: [  33 1598 4991]
# θ[idθ]: [0.0067 0.3197 0.9983]
# Si_old_final: -0.0011092144960134197
# Si_c: (-0.0011379390887823616, 7.961101395616301e-10)
# Si: -0.0009123435628000915
# continue
# end inside
# ---Start cycle inside---
# c: 0.005242429916878453
# g: [0.00524243 0.00524243 0.00524243 ... 0.00524243 0.00524243 0.00524243]
# idθ: [  32 1648 4991]
# θ[idθ]: [0.0065 0.3297 0.9983]
# Si_old_final: -0.0009123435628000915
# Si_c: (-0.0009790596661485762, 7.961101395616301e-10)
# Si: -0.0007154009132702162
# continue
# end inside
# ---Start cycle inside---
# c: 0.005043830638586221
# g: [0.00504383 0.00504383 0.00504383 ... 0.00504383 0.00504383 0.00504383]
# idθ: [  30 1701 4990]
# θ[idθ]: [0.0061 0.3403 0.9981]
# Si_old_final: -0.0007154009132702162
# Si_c: (-0.0008201802435147906, 7.961101395616301e-10)
# Si: -0.00051837293324768
# continue
# end inside
# ---Start cycle inside---
# c: 0.004845231360293989
# g: [0.00484523 0.00484523 0.00484523 ... 0.00484523 0.00484523 0.00484523]
# idθ: [  29 1757 4990]
# θ[idθ]: [0.0059 0.3515 0.9981]
# Si_old_final: -0.00051837293324768
# Si_c: (-0.000661300820881005, 7.961101395616301e-10)
# Si: -0.00032134935867760705
# continue
# end inside
# ---Start cycle inside---
# c: 0.004646632082001757
# g: [0.00464663 0.00464663 0.00464663 ... 0.00464663 0.00464663 0.00464663]
# idθ: [  27 1815 4990]
# θ[idθ]: [0.0055 0.3631 0.9981]
# Si_old_final: -0.00032134935867760705
# Si_c: (-0.0005024213982472193, 7.961101395616301e-10)
# Si: -0.000124273960821899
# continue
# end inside
# ---Start cycle inside---
# c: 0.004448032803709525
# g: [0.00444803 0.00444803 0.00444803 ... 0.00444803 0.00444803 0.00444803]
# idθ: [  26 1876 4989]
# θ[idθ]: [0.0053 0.3753 0.9979]
# Si_old_final: -0.000124273960821899
# Si_c: (-0.00034354197561343373, 7.961101395616301e-10)
# Si: 7.2871587142477e-05
# search aP
# aP: 0.004448032803709525
# aP1_fin: 0.004448032803709525
# Flag1 == True
# break
# ----------------------------------------
# -----!Si_old_final: -0.000124273960821899
# -----!Si: 7.2871587142477e-05
# -----!aP_fin: 0.004448032803709525
# ----------------------------------------
# End

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

#print(phase_diagram)
phase_diagram[0][1] = 146.6
plt.scatter(*zip(*phase_diagram))
 
# ссылка про функции https://pythonworld.ru/tipy-dannyx-v-python/vse-o-funkciyax-i-ix-argumentax.html
plt.ylabel("T")
plt.xlabel("θ")

#plt.legend()
# Out:
# Text(0.5, 0, 'θ')

# %%
phase1 = [[0.5, 0.08758042042172726], [0.4321000000000001, 0.085404766873647], [0.6297000000000001, 0.08540406618127187], [0.25870000000000004, 0.07717105259113205], [0.6655000000000001, 0.07717814706650325], [0.19890000000000002, 0.06946004960384242], [0.7347000000000001, 0.06946039376920948], [0.17770000000000002, 0.06406017883568722], [0.8195000000000001, 0.06405926685536056], [0.1403, 0.05699803579939114], [0.8509000000000001, 0.0570050493950605], [0.11130000000000002, 0.05018590236486543], [0.8771000000000001, 0.05020121908022799], [0.08790000000000002, 0.04360916278858174], [0.8985000000000002, 0.043594950823291546], [0.07650000000000001, 0.03918650874625877], [0.9255000000000002, 0.03917867018565398], [0.058700000000000016, 0.03300966816013497], [0.9385000000000001, 0.03296453955017526], [0.04950000000000001, 0.028903457384893704], [0.9551000000000002, 0.028943423541063055], [0.03590000000000001, 0.023068068189009357], [0.9627000000000001, 0.023063605726248004], [0.028900000000000006, 0.01937168796080757], [0.9731000000000002, 0.019395652162062484], [0.022500000000000003, 0.01580558793508853], [0.9805000000000001, 0.015719449097764064], [0.016700000000000003, 0.012365485964960751], [0.9861000000000002, 0.01232978327154352], [0.011700000000000002, 0.009163955095830288], [0.9901000000000002, 0.009131403059062381], [0.007300000000000002, 0.0060992148443125525], [0.9927000000000001, 0.0060942792856015825], [0.006100000000000001, 0.005110144358886857], [0.9963000000000002, 0.005113679184012856], [0.4321000000000001, 0.085404766873647], [0.6297000000000001, 0.08540406618127187], [0.41530000000000006, 0.08409968157841674], [0.6613000000000001, 0.08409835426448889], [0.4015000000000001, 0.08282575403309678], [0.6869000000000001, 0.08282565676363876], [0.38930000000000003, 0.08157822851768393], [0.7085000000000001, 0.08157477056552395], [0.37850000000000006, 0.08035412502787831], [0.7275000000000001, 0.08034946221794839], [0.25870000000000004, 0.07717105259113205], [0.6655000000000001, 0.07717814706650325], [0.25270000000000004, 0.07598766217272931], [0.7049000000000001, 0.07599151851416616], [0.24710000000000004, 0.07482928515098039], [0.7307000000000001, 0.07482985350476926], [0.24150000000000002, 0.07367812696738069], [0.7509000000000001, 0.07367572811786693], [0.20330000000000004, 0.0705655724392405], [0.6965000000000001, 0.07057783864468137], [0.19890000000000002, 0.06946004960384242], [0.7347000000000001, 0.06946039376920948], [0.19430000000000003, 0.06834352479228756], [0.7587000000000002, 0.06835580122217713], [0.19010000000000002, 0.06726238419691923], [0.7775000000000001, 0.06726233038644366], [0.1859, 0.06618557496956498], [0.7933000000000001, 0.06617943736515346], [0.18170000000000003, 0.06511272367553218], [0.8073000000000001, 0.06512316480604113], [0.17770000000000002, 0.06406017883568722], [0.8195000000000001, 0.06405926685536056], [0.1539, 0.061053638215273584], [0.8037000000000001, 0.06106477477536606], [0.15050000000000002, 0.06003612888233626], [0.8177000000000001, 0.0600350715600178], [0.1469, 0.05899775203803485], [0.8299000000000002, 0.05900878434273362], [0.14370000000000002, 0.058008644725747224], [0.8409000000000001, 0.05799982832905366], [0.1403, 0.05699803579939114], [0.8509000000000001, 0.0570050493950605], [0.13710000000000003, 0.05601370644465491], [0.8599000000000001, 0.056004460206712084], [0.11990000000000002, 0.053076261337788797], [0.8505000000000001, 0.053082043845149536], [0.11690000000000002, 0.0520909734338926], [0.8601000000000002, 0.05210241228852016], [0.11410000000000002, 0.05113798261054673], [0.8689000000000001, 0.0511387136200013], [0.11130000000000002, 0.05018590236486543], [0.8771000000000001, 0.05020121908022799], [0.10850000000000003, 0.04923442437097323], [0.8845000000000002, 0.04925116843527904], [0.10590000000000002, 0.04831682718004393], [0.8915000000000002, 0.04833162729149824], [0.10330000000000002, 0.04740024895921313], [0.8979000000000001, 0.04740282746247571], [0.09030000000000002, 0.04451757465820258], [0.8919000000000001, 0.044509907254476955], [0.08790000000000002, 0.04360916278858174], [0.8985000000000002, 0.043594950823291546], [0.08550000000000002, 0.0427000942838672], [0.9047000000000002, 0.042700677922858435], [0.08330000000000001, 0.04183327849307516], [0.9105000000000002, 0.04182045326186018], [0.08090000000000001, 0.04092258536823234], [0.9159000000000002, 0.040946386321401886], [0.07870000000000002, 0.04005485179705171], [0.9209000000000002, 0.0400692825073149], [0.07650000000000001, 0.03918650874625877], [0.9255000000000002, 0.03917867018565398], [0.07430000000000002, 0.03831722678324127], [0.9299000000000002, 0.03831407878306874], [0.06450000000000002, 0.0355253178274765], [0.9261000000000001, 0.035532938158677155], [0.06250000000000001, 0.03467030416549143], [0.9305000000000001, 0.03467061406531105], [0.06050000000000001, 0.033812819910694014], [0.9347000000000002, 0.03383278325549814], [0.058700000000000016, 0.03300966816013497], [0.9385000000000001, 0.03296453955017526], [0.056700000000000014, 0.032146982887742113], [0.9423000000000001, 0.03216502301680301], [0.05490000000000001, 0.03133976069984674], [0.9457000000000002, 0.03132149564820451], [0.053100000000000015, 0.03053037734434087], [0.9491000000000002, 0.03054689043528758], [0.05130000000000001, 0.029718425325099055], [0.9521000000000002, 0.029711555895974826], [0.04950000000000001, 0.028903457384893704], [0.9551000000000002, 0.028943423541063055], [0.04210000000000001, 0.02618146852353326], [0.9521000000000002, 0.026203534301251268], [0.04050000000000001, 0.02539077917155244], [0.9549000000000002, 0.025380003382742544], [0.03890000000000001, 0.024595673591630042], [0.9577000000000002, 0.024615327038675812], [0.03750000000000001, 0.023872188963304335], [0.9603000000000002, 0.023845210943558553], [0.03590000000000001, 0.023068068189009357], [0.9627000000000001, 0.023063605726248004], [0.03450000000000001, 0.022337323590311514], [0.9651000000000002, 0.022341717427049195], [0.03310000000000001, 0.02160286044382242], [0.9673000000000002, 0.021602777843262654], [0.031700000000000006, 0.02086416105065125], [0.9693000000000002, 0.02083918555707451], [0.030300000000000004, 0.020120650334926583], [0.9711000000000002, 0.020043289416824334], [0.028900000000000006, 0.01937168796080757], [0.9731000000000002, 0.019395652162062484], [0.027500000000000004, 0.01861655915036085], [0.9747000000000001, 0.01861644472704181], [0.026300000000000004, 0.017944094067501908], [0.9763000000000002, 0.017890602423095835], [0.024900000000000005, 0.01717636002309357], [0.9779000000000002, 0.017221794240656348], [0.023700000000000002, 0.016493611467012958], [0.9793000000000002, 0.0165011962495779], [0.022500000000000003, 0.01580558793508853], [0.9805000000000001, 0.015719449097764064], [0.021300000000000003, 0.015111581111838504], [0.9819000000000002, 0.015107414338881449], [0.020100000000000003, 0.014410792827082613], [0.9831000000000002, 0.014431465606066491], [0.018900000000000004, 0.013702320989712772], [0.9841000000000002, 0.013681109060006384], [0.017900000000000003, 0.01308964292668414], [0.9851000000000002, 0.012980071569472668], [0.016700000000000003, 0.012365485964960751], [0.9861000000000002, 0.01232978327154352], [0.015700000000000002, 0.011740113390130896], [0.9871000000000002, 0.011732311416829547], [0.014700000000000001, 0.011108237571290714], [0.9879000000000002, 0.011045714010027515], [0.013700000000000002, 0.010468961375701446], [0.9887000000000001, 0.010407866313309658], [0.012700000000000001, 0.00982125935261863], [0.9895000000000002, 0.009819646619663936], [0.011700000000000002, 0.009163955095830288], [0.9901000000000002, 0.009131403059062381], [0.010700000000000001, 0.008495693770283858], [0.9907000000000001, 0.008490253338257476], [0.0099, 0.007942583256157742], [0.9913000000000002, 0.007895548796457888], [0.008900000000000002, 0.007251727776949229], [0.9917000000000001, 0.0072013882480891295], [0.008100000000000001, 0.006680233700764241], [0.9923000000000002, 0.006696579245026283], [0.007300000000000002, 0.0060992148443125525], [0.9927000000000001, 0.0060942792856015825], [0.009300000000000001, 0.007367927669861973], [0.9951000000000002, 0.007424040450194661], [0.0085, 0.006817916121421183], [0.9953000000000002, 0.006639561660870039], [0.007700000000000002, 0.006259262806334764], [0.9957000000000001, 0.0061635276417695214], [0.006900000000000002, 0.005690559863570603], [0.9959000000000001, 0.005491493653061613], [0.006100000000000001, 0.005110144358886857], [0.9963000000000002, 0.005113679184012856], [0.005300000000000001, 0.004516041041163306], [0.9965000000000002, 0.004543529702047434], [0.004500000000000001, 0.003905889393023809], [0.9967000000000001, 0.004027346953025239], [0.0039000000000000007, 0.003432115358650482], [0.9967000000000001, 0.003367420082636019], [0.0033000000000000004, 0.0029480900740729357], [0.9969000000000001, 0.0029603504661565483]]
#print(phase1)
plt.axis([None, None, 0.07, 0.09])
plt.scatter(*zip(*phase_diagram))

# %%
sum_th = phase_diagram[3][0]+phase_diagram[4][0]
print(sum_th)
sum_th = phase_diagram[153][0]+phase_diagram[154][0]
print(len(phase_diagram))
# Out:
# 0.9790000000000001
# 171

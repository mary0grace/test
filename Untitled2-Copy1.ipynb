# %%
import sympy as sp
sp.init_printing() 

x = sp.symbols('x') # Переменная x теперь содержит символ 'x'

x = sp.symbols('x') # Переменная x теперь содержит символ 'x'
f = x**2 - 2*x + 1  - 4 # Выражение для функции
f
# График функции
# %matplotlib inline
sp.plot(f, (x, -2, 4)); #sympy содержит свою функцию для быстрого построения графиков


sp.solve(f, x) #Корни уравнения f(x) = 0

#Первая производная
df = f.diff(x)
df

# Вычислить значение производной при x = 5:
df.subs(x, 5)

# Стационарные точки f'(x) = 0
sp.solve(df) # Точки, в которых производная равна 0

# Вторая производная
f.diff(x, 2) # тип экстремума. f''(x)>0 => найден минимум
# Out:
# 2

# %%
f
# Out:
#  2
# x  - 2⋅x - 3

# %%
df
# Out:
# 2⋅x - 2

# %%
f.diff(x, 2)
# Out:
# 2

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(1)
l,=ax.plot(range(5))
l.set_label('line 1')
ax.legend()
plt.show()
